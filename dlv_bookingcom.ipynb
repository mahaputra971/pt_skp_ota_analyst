# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/mahaputra971/pt_skp/output/daun-lebar-villas_2026_01_05_09_51_13/reviews_most_relevant.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              116 non-null    object
#  1   user_country          115 non-null    object
#  2   room_view             115 non-null    object
#  3   stay_duration         116 non-null    object
#  4   stay_type             116 non-null    object
#  5   review_post_date      116 non-null    object
#  6   review_title          116 non-null    object
#  7   rating                116 non-null    float64
#  8   original_lang         116 non-null    object
#  9   review_text_liked     70 non-null     object
#  10  review_text_disliked  51 non-null     object
#  11  full_review           116 non-null    object
#  12  en_full_review        65 non-null     object
#  13  found_helpful         116 non-null    int64
#  14  found_unhelpful       116 non-null    int64
#  15  owner_resp_text       0 non-null      float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 14.6+ KB

# %%
df.head()
# Out:
#    username    user_country                              room_view  \
# 0     Tejas  United Kingdom       Three Bedroom Private Pool Villa
# 1  Rajanand           India  Deluxe One Bedroom Private Pool Villa
# 2      John       Australia       Three Bedroom Private Pool Villa
# 3  Maleribe    South Africa         One Bedroom Private Pool Villa
# 4    Stella       Australia         Two Bedroom Private Pool Villa
#
#   stay_duration stay_type     review_post_date  \
# 0      2 nights     Group  07-10-2025 00:00:00
# 1      2 nights    Family  11-26-2025 00:00:00
# 2      3 nights    Family  10-17-2025 00:00:00
# 3      4 nights    Family  11-05-2024 00:00:00
# 4      5 nights     Group  07-29-2024 00:00:00
#
#                        review_title  rating original_lang  \
# 0  Lovely staff and lovely villas 🤗    10.0         en-us
# 1                          Pleasant     6.0            en
# 2      Would definetly stay again .     8.0            en
# 3                         Very good     8.0            en
# 4                              Okay     6.0            en
#
#                                    review_text_liked  \
# 0                     Nice location and lovely staff
# 1  property increase for transportation facuilty....
# 2  The pool was great with the kids although VERY...
# 3  The villa was great, very quiet and peaceful. ...
# 4  It is pretty but not worth the money. Probably...
#
#                                 review_text_disliked  \
# 0                                          Best vibe
# 1                                                NaN
# 2  Facilities such as iron & ironing board were v...
# 3  There was no electricity on my first night, I ...
# 4  It is so far away from everything and the food...
#
#                                          full_review  \
# 0  title: Lovely staff and lovely villas 🤗. liked...
# 1  title: Pleasant. liked: property increase for ...
# 2  title: Would definetly stay again . liked: The...
# 3  title: Very good. liked: The villa was great, ...
# 4  title: Okay. liked: It is pretty but not worth...
#
#                                       en_full_review  found_helpful  \
# 0  title: Lovely staff and lovely villas 🤗. liked...              0
# 1  title: Pleasant. liked: property increase for ...              0
# 2  title: Would definetly stay again . liked: The...              0
# 3  title: Very good. liked: The villa was great, ...              0
# 4  title: Okay. liked: It is pretty but not worth...              1
#
#    found_unhelpful  owner_resp_text
# 0                0              NaN
# 1                0              NaN
# 2                0              NaN
# 3                0              NaN
# 4                0              NaN

# %%
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              116 non-null    object
#  1   user_country          116 non-null    object
#  2   room_view             116 non-null    object
#  3   stay_duration         116 non-null    object
#  4   stay_type             116 non-null    object
#  5   review_post_date      116 non-null    object
#  6   review_title          116 non-null    object
#  7   rating                116 non-null    float64
#  8   original_lang         116 non-null    object
#  9   review_text_liked     116 non-null    object
#  10  review_text_disliked  116 non-null    object
#  11  full_review           116 non-null    object
#  12  en_full_review        116 non-null    object
#  13  found_helpful         116 non-null    int64
#  14  found_unhelpful       116 non-null    int64
#  15  owner_resp_text       116 non-null    float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 14.6+ KB

# %%
df.head()
# Out:
#    username    user_country                              room_view  \
# 0     Tejas  United Kingdom       Three Bedroom Private Pool Villa
# 1  Rajanand           India  Deluxe One Bedroom Private Pool Villa
# 2      John       Australia       Three Bedroom Private Pool Villa
# 3  Maleribe    South Africa         One Bedroom Private Pool Villa
# 4    Stella       Australia         Two Bedroom Private Pool Villa
#
#   stay_duration stay_type     review_post_date  \
# 0      2 nights     Group  07-10-2025 00:00:00
# 1      2 nights    Family  11-26-2025 00:00:00
# 2      3 nights    Family  10-17-2025 00:00:00
# 3      4 nights    Family  11-05-2024 00:00:00
# 4      5 nights     Group  07-29-2024 00:00:00
#
#                        review_title  rating original_lang  \
# 0  Lovely staff and lovely villas 🤗    10.0         en-us
# 1                          Pleasant     6.0            en
# 2      Would definetly stay again .     8.0            en
# 3                         Very good     8.0            en
# 4                              Okay     6.0            en
#
#                                    review_text_liked  \
# 0                     Nice location and lovely staff
# 1  property increase for transportation facuilty....
# 2  The pool was great with the kids although VERY...
# 3  The villa was great, very quiet and peaceful. ...
# 4  It is pretty but not worth the money. Probably...
#
#                                 review_text_disliked  \
# 0                                          Best vibe
# 1                                                  0
# 2  Facilities such as iron & ironing board were v...
# 3  There was no electricity on my first night, I ...
# 4  It is so far away from everything and the food...
#
#                                          full_review  \
# 0  title: Lovely staff and lovely villas 🤗. liked...
# 1  title: Pleasant. liked: property increase for ...
# 2  title: Would definetly stay again . liked: The...
# 3  title: Very good. liked: The villa was great, ...
# 4  title: Okay. liked: It is pretty but not worth...
#
#                                       en_full_review  found_helpful  \
# 0  title: Lovely staff and lovely villas 🤗. liked...              0
# 1  title: Pleasant. liked: property increase for ...              0
# 2  title: Would definetly stay again . liked: The...              0
# 3  title: Very good. liked: The villa was great, ...              0
# 4  title: Okay. liked: It is pretty but not worth...              1
#
#    found_unhelpful  owner_resp_text
# 0                0              0.0
# 1                0              0.0
# 2                0              0.0
# 3                0              0.0
# 4                0              0.0

# %%
def plot_barplot(data, x_col, y_col, title="", format_number="", x_label="", y_label="", colour_bar_set="3"):
    plt.figure(figsize=(10, max(6, len(data) * 0.4))) # Tinggi otomatis menyesuaikan banyaknya negara

    # --- 1. DETEKSI OTOMATIS: VERTIKAL ATAU HORIZONTAL? ---
    # Jika Y-nya angka, berarti Vertikal. Jika Y-nya teks, berarti Horizontal.
    if pd.api.types.is_numeric_dtype(data[y_col]):
        orientation = 'vertical'
        color_basis = data[y_col] # Warna ikut tinggi Y
    else:
        orientation = 'horizontal'
        color_basis = data[x_col] # Warna ikut panjang X (Jumlah)

    # --- 2. LOGIKA WARNA ---
    if colour_bar_set == "1": # Tinggi=Hijau
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    elif colour_bar_set == "2": # Tinggi=Merah
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn_r", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    else: # Mode 3 (Default Biru - Aman untuk Kategori)
        colors = ["#4c72b0"] * len(data)
        sm = None

    # --- 3. MEMBUAT PLOT ---
    barplot = sns.barplot(
        x=x_col, 
        y=y_col,
        data=data,
        palette=colors,
        hue=y_col if orientation == 'horizontal' else x_col, # Fix warning seaborn baru
        legend=False
    )

    # --- 4. MEMBERI LABEL ANGKA (SMART POSITIONING) ---
    for bar in barplot.patches:
        # Ambil dimensi batang
        width = bar.get_width()
        height = bar.get_height()
        
        # Tentukan nilai yang akan ditulis
        value = width if orientation == 'horizontal' else height
        if np.isnan(value): continue

        # Format label
        if isinstance(value, float):
            label_text = f"{format_number}{value:.2f}"
            if value.is_integer(): label_text = f"{format_number}{int(value)}"
        else:
            label_text = f"{format_number}{int(value)}"

        # Tentukan posisi teks
        if orientation == 'horizontal':
            # Jika horizontal, teks ditaruh di sebelah kanan ujung batang
            text_x = width + (data[x_col].max() * 0.01) # Beri sedikit jarak
            text_y = bar.get_y() + height / 2
            ha_align = 'left'
            color_text = 'black' # Teks hitam biar terbaca di background putih
        else:
            # Jika vertikal, teks ditaruh di tengah/atas batang
            text_x = bar.get_x() + width / 2
            text_y = bar.get_y() + height / 2
            ha_align = 'center'
            color_text = 'white'

        plt.text(
            text_x, 
            text_y, 
            label_text, 
            va='center', 
            ha=ha_align, 
            fontsize=10, 
            color=color_text, 
            weight='bold'
        )

    # Kosmetik
    plt.title(title, loc="center", fontsize=16, fontweight='bold', pad=20)
    plt.xlabel(x_label if x_label else x_col, fontsize=12)
    plt.ylabel(y_label if y_label else y_col, fontsize=12)
    
    if orientation == 'vertical':
        plt.grid(axis='y', linestyle='--', alpha=0.3)
    else:
        plt.grid(axis='x', linestyle='--', alpha=0.3) # Grid X untuk horizontal

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 1. Rating User

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap rating
'''
count_gender = df.groupby('rating').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="rating",
    y_col="jumlah", 
    title="rating",
    format_number="",
    x_label="Banyak",
    colour_bar_set="2"
)
# Out:
#    rating  jumlah
# 9    10.0      38
# 7     8.0      26
# 6     7.0      14
# 8     9.0      14
# 5     6.0       7
# 4     5.0       6
# 0     1.0       4
# 3     4.0       3
# 1     2.0       2
# 2     3.0       2

# %%
dislike_df = df[df['review_text_disliked'] != 0]
dislike_list = dislike_df['review_text_disliked'].tolist()

print(f"Total komentar dislike: {len(dislike_list)}")
print(f"Komentar dislike: {dislike_list}")
# Out:
# Total komentar dislike: 51
# Komentar dislike: ['Best vibe', 'Facilities such as iron & ironing board were very old and unsafe .', "There was no electricity on my first night, I couldn't bath. And the stuff didn't even bother letting me know upon arrival. T hey didn't make mean to provide hot water😩😩", 'It is so far away from everything and the food at the restaurant is not good. Be prepared to wait ages for a grab or gojek as they don’t really come around this area or pay for an expensive taxi from the hotel.', 'There was a smell in the bathroom. The young wait staff in the restaurant are friendly, but their English is very basic. They tend to congregate at the drink counter instead of seeing if the customers need anything. There was no ability to exchange or obtain local currency.', "It's a bit far to find places to eat/restaurants outside the location", 'The unit was a little bit not clean and the gecko was disturbing', 'Ants in our room. Stains on walls. Food was very poor', 'Location only.', 'Very far from town', 'Food was average, outside of the rooms needed cleaning. Hotel taxi was extremely expensive', 'There were several minor annoyances like the water heater being undersized for the room and running out of hot water before even filing a third of the tub. As for the other things, the staff was very responsive in handling them.', 'Pool was cold as no direct sunlight so maybe could do with a heater.', 'Nothing wrong with the hotel, but bali traffic, 4.1km can take 1.5hr.', 'Location', 'Housekeeping was a little lacking in some areas.', 'We booked a three bedroom villa but there is only 1 single master bedroom with a double bed and the other 2 bedrooms are with a single bed. So all bedrooms are not the same. They provided kitchen in villa but there is only fridge and electric kettle means no meaning of kitchen.', 'They do not change bed sheets. They just flip them over. The pool was broken down for three days. Construction noise in the villas will wake you up the morning. Very difficult to get taxi because the location is very remote. And when get a taxi it’s very expensive.', 'Food could be better, lots more room for improvement', 'The food selection could be wider for international visitors.', '-', 'Stayed in 108 Pala villa. Expect to have good air-conditioned when you are staying in hot country like Bali. Called front desk many times to fix the aircond, they sent technician twice, still not able to fix the aircond, technician said that the hotel staff will contact us for further action. Waited few hours didnt get any calls from hotel, thus decide to call again the front desk. They said still waiting for the manager answer. No answer till we all check out. And no single apologies from the hotel staff @ manager. Our aircond was put on 18degree with max fan, but the temperature is like 26degree with slow fan until morning.', 'Limited food and drink', 'Nothing', 'The villa was not the cleanest', 'Location is a bit deep in. No shops nearby..', 'The food, not very clean (cushions of chairs, toilets etc.) Alot of ants sometimes in the bed.', 'There was a ton of ants in my villa, I do understand that it’s located in the jungle & thats almost uncontrollable but I didn’t mind them in my villa however, on my bed & in my room was what I didn’t like. When I notified the staff they provided ant spray & that actually helped a lot. I also didn’t like the location for only one reason, the taxis come to the front desk when you call them & you have to walk all the way down along unpaved “road” to get to the front desk & at night that can be super scary because there’s no lights. I wish the hotel address was linked to where the villas actually are, this would make pickups/drop offs easier — or a safer, smoother road with lights to walk down to the front desk.', 'Lage ist ca. 20 km außerhalb von Ubud (ca. 1 Stunde Fahrtzeit mit dem Roller) Wenn man keinen eigenen Roller / Auto hat, ist die Unterkunft sehr schwer zu erreichen Preise im Restaurant recht teuer', 'pour l ...

# %%
like_df = df[df['review_text_liked'] != 0]
like_list = like_df['review_text_liked'].tolist()

print(f"Total komentar like: {len(like_list)}")
print(f"Komentar like: {like_list}")
# Out:
# Total komentar like: 70
# Komentar like: ['Nice location and lovely staff', 'property increase for transportation facuilty.....', 'The pool was great with the kids although VERY cold . It was nice to have a restaurant on the premises .', "The villa was great, very quiet and peaceful. But very far from Ubud center. Gojek and Grab doesn't work around here and the villa changes 5times the price of Grab.", 'It is pretty but not worth the money. Probably good for a family but I don’t recommend it if you are young.', 'Food was very average and expensive. Staff were very intense at watching you but very slow table service. No comfortable seating in the villas. Hard to get taxi or gojek. Yoga had to be paid for which is silly seeing as how much you spend on accomodation. No hot water for two days. Wifi very bad.', 'The villa rooms are amazing, with an open living area, private pool, and spacious bathroom. Breakfast is not extensive, but fine. The location suited our needs perfectly, but if you want to be near the action, this is not the place for you.', 'I like almost all the things/facilities provided in this villa. Polite receptionist, fairly large and clean rooms, swimming pool, atmosphere, food, wifi, etc', 'Peaceful place to clear your mind and soul', 'Bed was very comfortable. Shower was excellent. Staff were amazing!!', 'Tranquil and clean', 'Very quiet place and helpful staff.', 'The location was amazing for serenity and some isolation', 'It was calm and relatively secluded. Good place to choose if you want to be away from the hustle and bustle.', 'Great location and staff were helpful especially Easter! Very clean and comfortable . Villa was well kept and beautiful. Perfect stay', 'Beautiful light interior and surrounding of rice fields.', 'Design and ambiance', "Amazing staff. A+++++ I can't say enough about how lovely they were during our stay. Son was sick, got great advice about the hospital and then staff turned up in our villa with food for him to try and a get well soon card. My birthday and staff arrived with a cake and card signed by all staff for me.", 'Property is good and stay was also good, if you are searching for a good atmosphere then you must stay here.', 'The staff were very nice. The nature around the place is beautiful.', 'Everything was perfect. The service was really good, the staff were courteous and friendly.', 'The villa is beautiful, though it is pretty hard to reach.', 'The villa was very clean and the environment was serene and relaxing! The staff were very helpful and ensured that we were comfortable.', 'Excellent villas with private pool and spacious. Great service.', "The staff's competency, friendliness, and professionalism.", 'Staff were very friendly and the romantic dinner organised by Widiya for my parent’s birthday was perfect. Thank you', 'Very nice, perfect for family', 'Quiet and peaceful location', 'Nice villa with beautiful scenic area', 'The villa was beautiful', 'I liked everything abt this place its a gate away from the city for few days. Staff were so friendly food was amazing esp the floating breakfast...', 'Nice villa n view', 'Staff were friendly', 'We called it the bali bingo breakfast every thing was lovely just language barrier sometimes so if you like tea with milk ask for sou sou very friendly staff could not try to help more then they did I would definitely visit again', 'Awesome and cool place.. All the staffs were friendly and fast..', 'Friendly staff', 'I loved the staff, they were so nice & super attentive. The most friendly & accommodating hotel staff I have come across in my history of traveling. I wish I could have brought them back to America just to feel there good vibes everyday lol. I also loved how spacious the villas are, how secluded and quite the atmosphere was — believe it or not, I enjoyed the sounds of the animals every morning. The property is exactly what I need, peace and zen.', 'Schöne Lage inmitten der Reisfelder Toller eigener Pool Schöne eigene Villa, gute Ausstattung Sehr ...

# %% [markdown]
# ## 2. User's Country

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap user_country
'''
count_gender = df.groupby('user_country').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="user_country", 
    title="user_country",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#             user_country  jumlah
# 11             Indonesia      16
# 1              Australia      14
# 10                 India       8
# 21          Saudi Arabia       8
# 14              Malaysia       8
# 7                 France       8
# 8                Germany       7
# 15           Netherlands       4
# 33         United States       3
# 22             Singapore       3
# 23          South Africa       3
# 31  United Arab Emirates       3
# 28                Taiwan       2
# 24           South Korea       2
# 13                 Italy       2
# 16           New Zealand       2
# 26           Switzerland       2
# 25                 Spain       2
# 3                 Canada       2
# 32        United Kingdom       2
# 12               Ireland       2
# 29              Thailand       1
# 30                Turkey       1
# 27                 Syria       1
# 0                      0       1
# 20                Russia       1
# 19              Portugal       1
# 18                Poland       1
# 9                Hungary       1
# 6                Estonia       1
# 5         Czech Republic       1
# 4                  Chile       1
# 2                Belgium       1
# 17                  Oman       1

# %% [markdown]
# ## 3. Owner Respone

# %%
owner_df = df[df['owner_resp_text'] != 0]
owner_df = owner_df['owner_resp_text'].tolist()

print(f"Total komentar owner_resp_text: {len(owner_df)}")
print(f"Komentar owner_resp_text: {owner_df}")
# Out:
# Total komentar owner_resp_text: 0
# Komentar owner_resp_text: []

# %% [markdown]
# ## 4. Room View

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap room_view
'''
count_gender = df.groupby('room_view').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="room_view", 
    title="room_view",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#                                room_view  jumlah
# 3       Three Bedroom Private Pool Villa      32
# 2         One Bedroom Private Pool Villa      31
# 4         Two Bedroom Private Pool Villa      30
# 1  Deluxe One Bedroom Private Pool Villa      22
# 0                                      0       1

# %% [markdown]
# ## 5. Stay Duration

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_duration
'''
count_gender = df.groupby('stay_duration').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="stay_duration", 
    title="stay_duration",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#   stay_duration  jumlah
# 1      2 nights      35
# 0       1 night      26
# 2      3 nights      26
# 3      4 nights      11
# 4      5 nights       7
# 5      6 nights       6
# 6      7 nights       4
# 7      8 nights       1

# %% [markdown]
# ## 6. Stay Type

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_type
'''
stay_type = df.groupby('stay_type').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(stay_type)  
plot_barplot(
    data=stay_type,
    x_col="jumlah",
    y_col="stay_type", 
    title="stay_type",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#         stay_type  jumlah
# 0          Couple      49
# 1          Family      40
# 2           Group      25
# 3  Solo traveller       2

# %% [markdown]
# ## 7. Tahun Review

# %%
# --- 1. DATA PREPARATION ---

# Pastikan kolom tanggal bertipe datetime
# Jika format tanggalmu beda (misal: "12 Dec 2023"), pandas biasanya otomatis mengenali
df['review_post_date'] = pd.to_datetime(df['review_post_date'])

# Ekstrak tahun ke kolom baru
df['year'] = df['review_post_date'].dt.year

# Hitung jumlah review per tahun dan URUTKAN BERDASARKAN TAHUN (sort_index)
# Kita pakai sort_index() agar tahunnya urut (2020, 2021, 2022...), bukan acak.
year_counts = df['year'].value_counts().sort_index()

# Konversi ke DataFrame agar mudah di-plot seaborn
year_df = year_counts.reset_index()
year_df.columns = ['tahun', 'jumlah']

# --- 2. VISUALISASI (Best Practice) ---

# plt.figure(figsize=(10, 6))

# Gunakan satu warna (misal: biru) karena ini data waktu, tidak perlu warna-warni 
# kecuali Anda ingin menghighlight tahun tertentu.
plot_barplot(
    data=year_df,
    x_col="tahun",
    y_col="jumlah", 
    title="jumlah",
    format_number="",
    x_label="tahun",
    colour_bar_set="1"
)
# year_df

# %%
df['Year'] = df['review_post_date'].dt.year

# Reset index agar 'Year' kembali menjadi kolom
rating_year = df.groupby('Year')['rating'].mean().reset_index()

# Opsional: Urutkan tahun biar rapi
rating_year = rating_year.sort_values('Year')

print(rating_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_year, 
    x_col="Year", 
    y_col="rating", 
    title="Rata-rata Rating per Tahun", 
    x_label="Tahun",
    y_label="Skor Rating",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#    Year    rating
# 0  2023  8.289855
# 1  2024  6.861111
# 2  2025  8.272727

# %%
# Filter dulu: Ambil hanya data yang 'review_text_disliked' BUKAN 0
filtered_df = df[df['review_text_disliked'] != 0]

# Baru di-grouping
dislike_by_year = filtered_df.groupby('Year')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Tahun ===")
for year, comments in dislike_by_year.items():
    print(f"Tahun {year}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per
Rezension die ich hier auf Booking mache, aber die aufjedenfall machen möchte, damit anderen nicht das selbe passiert wie uns. Es wird im Internet angegeben das Hotel würde sich in Ubud befinden, jedoch ist es 40min vom Ubud zentrum entfernt. Das Hotel stellt auch garkeine Möglichkeiten bereit um ins Zentrum oder woanders hinzukommen. Keine Motorbike‘s, keine Autos zur Verfügung. Selbst gojek und grab fahren da nicht hin, was hieß, dass wir quasi einen Tag im Hotel gefangen waren, da wir uns nicht fortbewegen konnten. Rundherum nur Reisfelder und jungle das wars. Zum Glück hatten wir einen Freund der in Bali lebt, der uns mit sein Auto abholen konnte. Mussten dann die restlichen Tage einen privaten Fahrer buchen. All dies führte unnötig zu mehr kosten. Zudem gab es auch Probleme im Zimmer. Als wir die Toilette spühlen wollten funktioniert das WC nicht. Es wurde im Hotel auch nach dreimaliger Ansprache nichts gemacht, sodass wir das WC nicht nutzen konnten. Sie meinten jemand würde kommen doch keiner kam. Unmöglich! Wir sind Vegetarier, bei der Bestellung des Frühstückes, wurden wir mit Fleisch serviert. Also sogut wie alles was schief laufen kann lief schief. Auch andere Hotelgäste beschwerten sich vor ort bei der Ankunft über den Ort des Hotels, da sie auch wie wir dachten sie hätten in Ubud gebucht und festgestellt wie weit sie von allem sind.Also Alle die Zentral buchen möchten und in Ubud sein möchten und nicht irgendwo im Nirgendwo, der sollte die Finger von diesem Hotel lassen. Hier seid ihr nämlich lost. Das Personal ist euch nämlich auch keine Hilfe.', 'نظافة غرفة النوم ودورة المياة فقط', 'Absolut dreckig und der Manager war einfach super unfreundlich. Lage war echt okay.', 'villany sangat bagus dan bersih, suka bgt sm villany, cocok bgt suasanany tenang, nyaman']
# ------------------------------
# Tahun 2025: Ditemukan 5 komentar like.
# ['Nice location and lovely staff', 'property increase for transportation facuilty.....', 'The pool was great with the kids although VERY cold . It was nice to have a restaurant on the premises .', 'Excellent villas with private pool and spacious. Great service.', 'TODO....la ubicación alejado del ruido muy tranquilo en medio de los bosques y plantaciones de arroz']
# ------------------------------

# %%
# Reset index agar 'Year' kembali menjadi kolom
rating_room_year = filtered_df.groupby('room_view')['rating'].mean().reset_index()

rating_room_year = rating_room_year[rating_room_year!= 0]

# Opsional: Urutkan tahun biar rapi
rating_room_year = rating_room_year.sort_values('rating')

print(rating_room_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_room_year , 
    x_col="rating", 
    y_col="room_view", 
    title="Rata-rata Rating per room_view", 
    x_label="Skor Rating",
    y_label="Room View",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#                                room_view    rating
# 2         One Bedroom Private Pool Villa  6.708333
# 1  Deluxe One Bedroom Private Pool Villa  7.333333
# 3       Three Bedroom Private Pool Villa  7.625000
# 0                                    NaN  8.000000
# 4         Two Bedroom Private Pool Villa  8.764706
# /tmp/ipykernel_29537/1757560589.py:27: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   barplot = sns.barplot(

# %%
filtered_df = df[df['review_text_disliked'] != 0].copy()
# Baru di-grouping
dislike_by_room_view = filtered_df.groupby('room_view')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Kamar ===")
for room_view, comments in dislike_by_room_view.items():
    print(f"Pada {room_view}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per Kamar ===
# Pada 0: Ditemukan 1 komentar dislike.
# ['There was a ton of ants in my villa, I do understand that it’s located in the jungle & thats almost uncontrollable but I didn’t mind them in my villa however, on my bed & in my room was what I didn’t like. When I notified the staff they provided ant spray & that actually helped a lot. I also didn’t like the location for only one reason, the taxis come to the front desk when you call them & you have to walk all the way down along unpaved “road” to get to the front desk & at night that can be super scary because there’s no lights. I wish the hotel address was linked to where the villas actually are, this would make pickups/drop offs easier — or a safer, smoother road with lights to walk down to the front desk.']
# ------------------------------
# Pada Deluxe One Bedroom Private Pool Villa: Ditemukan 9 komentar dislike.
# ["It's a bit far to find places to eat/restaurants outside the location", 'Location only.', 'Very far from town', 'There were several minor annoyances like the water heater being undersized for the room and running out of hot water before even filing a third of the tub. As for the other things, the staff was very responsive in handling them.', 'Nothing wrong with the hotel, but bali traffic, 4.1km can take 1.5hr.', 'They do not change bed sheets. They just flip them over. The pool was broken down for three days. Construction noise in the villas will wake you up the morning. Very difficult to get taxi because the location is very remote. And when get a taxi it’s very expensive.', 'Nothing', 'Lage ist ca. 20 km außerhalb von Ubud (ca. 1 Stunde Fahrtzeit mit dem Roller) Wenn man keinen eigenen Roller / Auto hat, ist die Unterkunft sehr schwer zu erreichen Preise im Restaurant recht teuer', 'المسبح غير نضيف ولا ينصح به تركت الباب مغقلا بالمفتاح ولما عدت وجدته مفتوحا لا توجد خصوصيه حيث المار بالممر يستطيع رؤية من هو داخل الفله']
# ------------------------------
# Pada One Bedroom Private Pool Villa: Ditemukan 20 komentar dislike.
# ["There was no electricity on my first night, I couldn't bath. And the stuff didn't even bother letting me know upon arrival. T hey didn't make mean to provide hot water😩😩", 'There was a smell in the bathroom. The young wait staff in the restaurant are friendly, but their English is very basic. They tend to congregate at the drink counter instead of seeing if the customers need anything. There was no ability to exchange or obtain local currency.', 'The unit was a little bit not clean and the gecko was disturbing', 'Ants in our room. Stains on walls. Food was very poor', 'Location', 'Food could be better, lots more room for improvement', 'The food selection could be wider for international visitors.', 'The villa was not the cleanest', 'Location is a bit deep in. No shops nearby..', 'pour le prix élevé pour le pays, les linges sont pas tous propres, les murs fissurés le personnel assez froid.', 'Spinnenwebben in de hoek van de badkamer. Geen spinnen aangetroffen.', 'Der Aussenbereich der Villa, Wohnzimmer und Pool, waren nicht ganz sauber, hier dürfte mehr investiert werden. Auch das Bad wirkte, obwohl es jeden Tag geputzt wurde unsauber - viele Kalkablagerungen und Schimmel in der Dusche. Zudem ist die Anlage etwas abgelegen. Wer kein eigenes Auto oder Bike hat ist darauf angewiesen sich vom Hotel Fahrer zu bestellen - Online Taxi Apps funktionieren dort nicht.', 'El aseo olía muy mal siempre, desde el primer día que llegamos, había mucha humedad y era un poco insoportable', 'далеко от всех достопримечательностей. мы были на байке, поэтому в принципе нормально. поехать поесть в ближайшее заведение с хорошими отзывами, не Балийская кухня, надо ехать 20-25 минут. один день был дождь и брали еду в ресторане этого места, не понравилось вообще, только пицца нормальная, остальное не советую. вечером очень много Комаров. сама вил
# ['Best vibe', 'Facilities such as iron & ironing board were very old and unsafe .', 'Housekeeping was a little lacking in some areas.', 'We booked a three bedroom villa but there is only 1 single master bedroom with a double bed and the other 2 bedrooms are with a single bed. So all bedrooms are not the same. They provided kitchen in villa but there is only fridge and electric kettle means no meaning of kitchen.', '-', 'Stayed in 108 Pala villa. Expect to have good air-conditioned when you are staying in hot country like Bali. Called front desk many times to fix the aircond, they sent technician twice, still not able to fix the aircond, technician said that the hotel staff will contact us for further action. Waited few hours didnt get any calls from hotel, thus decide to call again the front desk. They said still waiting for the manager answer. No answer till we all check out. And no single apologies from the hotel staff @ manager. Our aircond was put on 18degree with max fan, but the temperature is like 26degree with slow fan until morning.', "A la suite d'une intoxication alimentaire subie par mon mari, nous avons demandé de pouvoir annuler notre réservation sans frais afin de pouvoir loger près de l'hôpital et de l'aéroport car un rapatriement allait peut-être être nécessaire. Mais la direction n'a pas voulu faire de geste pour nous et nous avons dû donc honorer notre réservation et faire plusieurs aller-retours de plus d'1h30 entre l'hôpital et la villa fort excentrée de la ville. Dommage ce manque d'empathie .... Sinon, odeurs de moisissures dans les chambres et traces de moisissures dans le frigo, pas de nécessaire pour manger ou boire si ce n'est 2-3 fourchettes, et quelques assiettes.", 'Ik denk dat wij een beetje pech hadden. Het stormde met regen en onweer. Waardoor er veelste veel vliegende beestjes onstonden. Hierdoor konden we niet fatsoenlijk naar buiten of zitten in de open air woonkamer.', "Ligging (te ver af van Ubud). Presentatie (foto's) riepen ander beeld op dan werkelijkheid.", 'sayang BANGET, baru dateng d suguhi sm staf yg sangat kurang ramah tumben bgt nginep d suguhi sm staff yg kaya gini 😂 d tulis chek in jam 2 tapi sampai sana baru masuk jam stg 4 itupun krn komplain berkali”, apa lg bawa temen yg lg hamil n bwa anak kecil, sayang bgt villa bagus gara” satu staf jadi kurang nyaman padahal staf yg lain ramah', 'El precio de la Villa me parece excesivo ya que está en mitad de la nada y la parte de la cocina no es cerrada, por la noche hay muchos bichos y no puedes hacer vida. Deberían cerrarlo e indicar que no es cocina como tal sino una encimera con un lavabo y una nevera. Está muy retirado y necesitarás contratar un taxi privado para que te recoja y te lleve donde quieras. Grab y la otra aplicación no suelen llegar.']
# ------------------------------
# Pada Two Bedroom Private Pool Villa: Ditemukan 10 komentar dislike.
# ['It is so far away from everything and the food at the restaurant is not good. Be prepared to wait ages for a grab or gojek as they don’t really come around this area or pay for an expensive taxi from the hotel.', 'Food was average, outside of the rooms needed cleaning. Hotel taxi was extremely expensive', 'Pool was cold as no direct sunlight so maybe could do with a heater.', 'Limited food and drink', 'The food, not very clean (cushions of chairs, toilets etc.) Alot of ants sometimes in the bed.', 'Die Lage war doch sehr weit ab vom Schuss.', 'Läheduses polnud midagi teha. Basseini ääres ei saanud puhata kuna polnud lamamistoole', 'Jediné mínus na celém ubytování je stav koupelen. S tím je spojena i cena, která není tedy úplně jedna z nejlevnějších. Koupelna jako taková, je v pořádku, hezky zařízená, bohužel byla přítomna plíseň především na stropě. Chápu že je na Bali vysoká vlhkost, ale vzhledem k té ceně za ubytování, by tohle měli co nejdříve vyřešit. Kazí to celkový dojem hned po příjezdu.', 'Hersey mükemmeldi', 'Loin de tout mais il suffit du chauffeur pour aller et venir']
# ------------------------------

# %%
sns.lineplot(data=df, x='review_post_date', y='rating')
# Out:
# <Axes: xlabel='review_post_date', ylabel='rating'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
# Out:
# /tmp/ipykernel_29537/2148740873.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.set_index(date_col).resample('M').size()
# review_post_date
# 2023-08-31    12
# 2023-07-31    11
# 2023-02-28    10
# 2023-09-30     8
# 2023-10-31     8
# 2024-01-31     6
# 2023-06-30     5
# 2024-02-29     5
# 2024-08-31     4
# 2024-05-31     4
# 2024-07-31     4
# 2023-04-30     4
# 2023-11-30     4
# 2024-04-30     3
# 2023-03-31     3
# 2024-10-31     3
# 2023-12-31     2
# 2023-05-31     2
# 2024-06-30     2
# 2024-09-30     2
# 2025-07-31     2
# 2025-05-31     1
# 2025-11-30     1
# 2025-10-31     1
# 2025-09-30     1
# 2025-08-31     1
# 2025-06-30     1
# 2025-12-31     1
# 2025-04-30     1
# 2025-03-31     1
# 2024-12-31     1
# 2024-11-30     1
# 2024-03-31     1
# 2025-02-28     0
# 2025-01-31     0
# dtype: int64

# %%
import pandas as pd

# 1. Pastikan kolom target sudah format datetime
col_name = 'review_post_date'  # Sesuaikan nama kolom tanggal Anda
df[col_name] = pd.to_datetime(df[col_name], errors='coerce')

# 2. Urutan bulan yang benar (agar tidak terurut abjad April duluan)
bulan_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 
    'July', 'August', 'September', 'October', 'November', 'December'
]

# 3. Ambil nama bulan dan hitung
# dt.month_name() mengambil nama bulan (Jan, Feb, dst) mengabaikan tahun
monthly_counts = df[col_name].dt.month_name().value_counts()

# 4. Urutkan hasil sesuai kalender (bukan jumlah terbanyak)
monthly_counts = monthly_counts.reindex(bulan_order, fill_value=0)

# 5. Tampilkan Hasil
print("--- Total Data Per Bulan (Akumulasi Semua Tahun) ---")
print(monthly_counts.sort_values(ascending=False))

# --- Opsional: Tampilkan dalam Grafik Batang ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
monthly_counts.plot(kind='bar', color='teal')
plt.title('Total Review Berdasarkan Bulan (Musiman)')
plt.xlabel('Bulan')
plt.ylabel('Total Jumlah Review')
plt.xticks(rotation=45)
plt.show()
# Out:
# --- Total Data Per Bulan (Akumulasi Semua Tahun) ---
# review_post_date
# July         17
# August       17
# February     15
# October      12
# September    11
# April         8
# June          8
# May           7
# January       6
# November      6
# March         5
# December      4
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
# Out:
# /tmp/ipykernel_29537/2148740873.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.set_index(date_col).resample('M').size()
# review_post_date
# 2023-08-31    12
# 2023-07-31    11
# 2023-02-28    10
# 2023-09-30     8
# 2023-10-31     8
# 2024-01-31     6
# 2023-06-30     5
# 2024-02-29     5
# 2024-08-31     4
# 2024-05-31     4
# 2024-07-31     4
# 2023-04-30     4
# 2023-11-30     4
# 2024-04-30     3
# 2023-03-31     3
# 2024-10-31     3
# 2023-12-31     2
# 2023-05-31     2
# 2024-06-30     2
# 2024-09-30     2
# 2025-07-31     2
# 2025-05-31     1
# 2025-11-30     1
# 2025-10-31     1
# 2025-09-30     1
# 2025-08-31     1
# 2025-06-30     1
# 2025-12-31     1
# 2025-04-30     1
# 2025-03-31     1
# 2024-12-31     1
# 2024-11-30     1
# 2024-03-31     1
# 2025-02-28     0
# 2025-01-31     0
# dtype: int64
