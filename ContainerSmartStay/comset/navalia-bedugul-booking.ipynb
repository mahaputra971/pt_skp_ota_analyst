# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/mahaputra777/pt_skp/ContainerSmartStay/booking_review_css.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              63 non-null     object
#  1   user_country          63 non-null     object
#  2   room_view             62 non-null     object
#  3   stay_duration         63 non-null     object
#  4   stay_type             63 non-null     object
#  5   review_post_date      63 non-null     object
#  6   review_title          63 non-null     object
#  7   rating                63 non-null     float64
#  8   original_lang         63 non-null     object
#  9   review_text_liked     43 non-null     object
#  10  review_text_disliked  31 non-null     object
#  11  full_review           63 non-null     object
#  12  en_full_review        29 non-null     object
#  13  found_helpful         63 non-null     int64
#  14  found_unhelpful       63 non-null     int64
#  15  owner_resp_text       28 non-null     object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 8.0+ KB

# %%
df.head()
# Out:
#   username    user_country             room_view stay_duration  \
# 0      Fry  United Kingdom  Superior Double Room      2 nights
# 1   Thomas  United Kingdom  Superior Double Room       1 night
# 2  Suryadi       Indonesia  Superior Double Room       1 night
# 3     Jane       Indonesia  Standard Double Room       1 night
# 4     John           Qatar  Superior Double Room       1 night
#
#         stay_type     review_post_date  \
# 0  Solo traveller  06-23-2025 00:00:00
# 1  Solo traveller  03-05-2026 00:00:00
# 2          Couple  10-01-2025 00:00:00
# 3          Couple  09-25-2025 00:00:00
# 4          Family  05-04-2025 00:00:00
#
#                                         review_title  rating original_lang  \
# 0                                        Exceptional    10.0            en
# 1                                             Superb     9.0            en
# 2                                        Exceptional    10.0            en
# 3  A cozy stay with warm hospitality in a beautif...    10.0         en-us
# 4  Really helpful owner and comfortable room exac...    10.0            en
#
#                                    review_text_liked  \
# 0                  The concept and Ari, the manager.
# 1  Very lovely man running this place, he was ver...
# 2  This is my second stay at your property, and I...
# 3  I loved the cozy and comfortable bed with the ...
# 4  The location was great close to the lake and B...
#
#                                 review_text_disliked  \
# 0                                                NaN
# 1  Towels and bedding could have been a bit cleaner.
# 2                                            Nothing
# 3                Nothing at all, I liked everything.
# 4                                                NaN
#
#                                          full_review  \
# 0  title: Exceptional. liked: The concept and Ari...
# 1  title: Superb. liked: Very lovely man running ...
# 2  title: Exceptional. liked: This is my second s...
# 3  title: A cozy stay with warm hospitality in a ...
# 4  title: Really helpful owner and comfortable ro...
#
#                                       en_full_review  found_helpful  \
# 0  title: Exceptional. liked: The concept and Ari...              0
# 1  title: Superb. liked: Very lovely man running ...              0
# 2  title: Exceptional. liked: This is my second s...              0
# 3  title: A cozy stay with warm hospitality in a ...              0
# 4  title: Really helpful owner and comfortable ro...              0
#
#    found_unhelpful                                    owner_resp_text
# 0                0  Thank you for your review and glad to know you...
# 1                0  Thank you for your review. Special case : we w...
# 2                0  Dear Mr. Suryadi Apologies for the late respon...
# 3                0  Dear Jane, First of all, apol9gira for the lar...
# 4                0  Dear John. Thank you for your perfect review, ...

# %%
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              63 non-null     object
#  1   user_country          63 non-null     object
#  2   room_view             63 non-null     object
#  3   stay_duration         63 non-null     object
#  4   stay_type             63 non-null     object
#  5   review_post_date      63 non-null     object
#  6   review_title          63 non-null     object
#  7   rating                63 non-null     float64
#  8   original_lang         63 non-null     object
#  9   review_text_liked     63 non-null     object
#  10  review_text_disliked  63 non-null     object
#  11  full_review           63 non-null     object
#  12  en_full_review        63 non-null     object
#  13  found_helpful         63 non-null     int64
#  14  found_unhelpful       63 non-null     int64
#  15  owner_resp_text       63 non-null     object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 8.0+ KB

# %%
df.head()
# Out:
#   username    user_country             room_view stay_duration  \
# 0      Fry  United Kingdom  Superior Double Room      2 nights
# 1   Thomas  United Kingdom  Superior Double Room       1 night
# 2  Suryadi       Indonesia  Superior Double Room       1 night
# 3     Jane       Indonesia  Standard Double Room       1 night
# 4     John           Qatar  Superior Double Room       1 night
#
#         stay_type     review_post_date  \
# 0  Solo traveller  06-23-2025 00:00:00
# 1  Solo traveller  03-05-2026 00:00:00
# 2          Couple  10-01-2025 00:00:00
# 3          Couple  09-25-2025 00:00:00
# 4          Family  05-04-2025 00:00:00
#
#                                         review_title  rating original_lang  \
# 0                                        Exceptional    10.0            en
# 1                                             Superb     9.0            en
# 2                                        Exceptional    10.0            en
# 3  A cozy stay with warm hospitality in a beautif...    10.0         en-us
# 4  Really helpful owner and comfortable room exac...    10.0            en
#
#                                    review_text_liked  \
# 0                  The concept and Ari, the manager.
# 1  Very lovely man running this place, he was ver...
# 2  This is my second stay at your property, and I...
# 3  I loved the cozy and comfortable bed with the ...
# 4  The location was great close to the lake and B...
#
#                                 review_text_disliked  \
# 0                                                  0
# 1  Towels and bedding could have been a bit cleaner.
# 2                                            Nothing
# 3                Nothing at all, I liked everything.
# 4                                                  0
#
#                                          full_review  \
# 0  title: Exceptional. liked: The concept and Ari...
# 1  title: Superb. liked: Very lovely man running ...
# 2  title: Exceptional. liked: This is my second s...
# 3  title: A cozy stay with warm hospitality in a ...
# 4  title: Really helpful owner and comfortable ro...
#
#                                       en_full_review  found_helpful  \
# 0  title: Exceptional. liked: The concept and Ari...              0
# 1  title: Superb. liked: Very lovely man running ...              0
# 2  title: Exceptional. liked: This is my second s...              0
# 3  title: A cozy stay with warm hospitality in a ...              0
# 4  title: Really helpful owner and comfortable ro...              0
#
#    found_unhelpful                                    owner_resp_text
# 0                0  Thank you for your review and glad to know you...
# 1                0  Thank you for your review. Special case : we w...
# 2                0  Dear Mr. Suryadi Apologies for the late respon...
# 3                0  Dear Jane, First of all, apol9gira for the lar...
# 4                0  Dear John. Thank you for your perfect review, ...

# %%
def plot_barplot(data, x_col, y_col, title="", format_number="", x_label="", y_label="", colour_bar_set="3"):
    plt.figure(figsize=(10, max(6, len(data) * 0.4))) # Tinggi otomatis menyesuaikan banyaknya negara

    # --- 1. DETEKSI OTOMATIS: VERTIKAL ATAU HORIZONTAL? ---
    # Jika Y-nya angka, berarti Vertikal. Jika Y-nya teks, berarti Horizontal.
    if pd.api.types.is_numeric_dtype(data[y_col]):
        orientation = 'vertical'
        color_basis = data[y_col] # Warna ikut tinggi Y
    else:
        orientation = 'horizontal'
        color_basis = data[x_col] # Warna ikut panjang X (Jumlah)

    # --- 2. LOGIKA WARNA ---
    if colour_bar_set == "1": # Tinggi=Hijau
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    elif colour_bar_set == "2": # Tinggi=Merah
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn_r", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    else: # Mode 3 (Default Biru - Aman untuk Kategori)
        colors = ["#4c72b0"] * len(data)
        sm = None

    # --- 3. MEMBUAT PLOT ---
    barplot = sns.barplot(
        x=x_col, 
        y=y_col,
        data=data,
        palette=colors,
        hue=y_col if orientation == 'horizontal' else x_col, # Fix warning seaborn baru
        legend=False
    )

    # --- 4. MEMBERI LABEL ANGKA (SMART POSITIONING) ---
    for bar in barplot.patches:
        # Ambil dimensi batang
        width = bar.get_width()
        height = bar.get_height()
        
        # Tentukan nilai yang akan ditulis
        value = width if orientation == 'horizontal' else height
        if np.isnan(value): continue

        # Format label
        if isinstance(value, float):
            label_text = f"{format_number}{value:.2f}"
            if value.is_integer(): label_text = f"{format_number}{int(value)}"
        else:
            label_text = f"{format_number}{int(value)}"

        # Tentukan posisi teks
        if orientation == 'horizontal':
            # Jika horizontal, teks ditaruh di sebelah kanan ujung batang
            text_x = width + (data[x_col].max() * 0.01) # Beri sedikit jarak
            text_y = bar.get_y() + height / 2
            ha_align = 'left'
            color_text = 'black' # Teks hitam biar terbaca di background putih
        else:
            # Jika vertikal, teks ditaruh di tengah/atas batang
            text_x = bar.get_x() + width / 2
            text_y = bar.get_y() + height / 2
            ha_align = 'center'
            color_text = 'white'

        plt.text(
            text_x, 
            text_y, 
            label_text, 
            va='center', 
            ha=ha_align, 
            fontsize=10, 
            color=color_text, 
            weight='bold'
        )

    # Kosmetik
    plt.title(title, loc="center", fontsize=16, fontweight='bold', pad=20)
    plt.xlabel(x_label if x_label else x_col, fontsize=12)
    plt.ylabel(y_label if y_label else y_col, fontsize=12)
    
    if orientation == 'vertical':
        plt.grid(axis='y', linestyle='--', alpha=0.3)
    else:
        plt.grid(axis='x', linestyle='--', alpha=0.3) # Grid X untuk horizontal

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 1. Rating User

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap rating
'''
count_gender = df.groupby('rating').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="rating",
    y_col="jumlah", 
    title="rating",
    format_number="",
    x_label="Banyak",
    colour_bar_set="2"
)
# Out:
#    rating  jumlah
# 7    10.0      19
# 5     8.0      16
# 4     7.0      10
# 6     9.0      10
# 3     6.0       3
# 1     3.0       2
# 2     5.0       2
# 0     1.0       1

# %%
dislike_df = df[df['review_text_disliked'] != 0]
dislike_list = dislike_df['review_text_disliked'].tolist()

print(f"Total komentar dislike: {len(dislike_list)}")
print(f"Komentar dislike: {dislike_list}")
# Out:
# Total komentar dislike: 31
# Komentar dislike: ['Towels and bedding could have been a bit cleaner.', 'Nothing', 'Nothing at all, I liked everything.', '-', 'Nothing', 'The mattress was almost inexistent', 'It start to getting rusty.', 'Nothing. All perfect!', 'The room was a bit humid - it seemed to us that air ventilation in the room did not work properly.', 'you can improve the bathroom. use the small low bathtub to avoid corrosion on the container body. use thin insulation to make the room more warm during night or morning', 'It would be nice to have an option for breakfast', 'Wifi was slightly slow. Tv was a bit difficult to use. Otherwise nice stay', 'Beds a little firm and a little noisy with the other guests having fun in the recreation area.', 'Not cosy. Very basic white interior withing metal container walls with cold white lights on the ceiling. We arrived on a cold rainy night. Without A/C or any metal wall insulation it was pretty hard to warm up. Hot water in the shower was also misbehaving.', 'Be aware of the fact that it can get very cold during the evening and night (1st half of Sep). Be ready to put some extra clothes on for sleeping. There is no heater available.', 'It had a bad smell,the bathroom Is mouldy and does not drain water properly,There was no shower holder.The location is hard to find a taxi', 'Nothing', 'Atap kanopi sedikit berisik kalau kena angin, mungkin perlu sedikit perbaikan.', 'Na ubytování je zima tak se na to pripravte. Je to způsobené ale počasím. Majitel za to nemůže Co nám vadilo je neustálý smrad pálení odpadků od sousedního domu.', "Petit déjeuner ; uniquement nasi goreng ou mie goreng livrés à l'hôtel Le froid et l'humidité la nuit Calme mais loin des commerces et restaurants", 'Logement humide. Manque un système de déshumidificateur ou chauffage pour contrer ce problème', 'Контейнеры имеют металлические козырьки, которые при ветре очень шумят. Если у вас есть беруши - возьмите, они могут понадобиться. Днём жарко в номере, но достаточно открыть окна и двери, но мы особо днём не сидели в номере - рядом есть места, где можно провести весь день. Вечером холодно - одеяла вас конечно согреют, но лучше берите с собой теплые вещи. Ну и номер тесноват, однако для задачи - переночевать день, два - самый раз.', 'Leider war das Wasser beim Duschen eher nur knapp warm. Da es an diesem Tag viel geregt hat und bewölkt war, wäre eine heisse dusche schön gewesen. Bei schönem Wetter oder in der trocken Saison bestimmt weniger ein Problem.', 'Très humide il fait assez froid dans les container (mais il avait plu) Pas de wifi qui marchait et compliqué l’eau chaude Rien du tout autour pour manger, prévoir un véhicule', 'La salle de bain rouillé et les tâches dans les draps - acces defonce', 'Mitten im Nichts, irgendwo an einem brüchigen Feldweg. Leider hatte es an dem Tag ein paar Stunden geregnet, und es war einfach alles feucht und klamm, ohne jemals wieder trocken zu werden', 'Le lenzuola non erano perfettamente pulite e il bagno era molto umido.', 'Die Dusche war sehr ekelhaft. Generell war es aufgrund der mangelnden Isolierung sehr kalt, wodurch wir uns erkältet hatten. Wir hatten über die Unterkunft einen Roller gemietet. Im Vergleich zu anderen Orten war es sehr teuer. Die wollten 150k pro Tag. Des Weiteren mussten wir feststellen, dass eine der Bremsen des Rollers während der Fahrt versagt hat. Zum Glück ist nichts passiert, aber es hätte schlimm für uns enden können.', "Les nuits sont froides et l'eau de la douche n'est pas chaude longtemps Les enfants font du bruit tard", 'ne parle pas anglais', 'Schimmel, laut in der Nacht, Kalt in der Nacht, heiss am Tag. Dies ist auch aufgrund der Lage im Norden. Man ist ziemlich abgelegen, ohne eigenes Motorrad oder Auto sehr schwierig herum zukommen, Taxis sehr teuer und keine Grabs']

# %%
like_df = df[df['review_text_liked'] != 0]
like_list = like_df['review_text_liked'].tolist()

print(f"Total komentar like: {len(like_list)}")
print(f"Komentar like: {like_list}")
# Out:
# Total komentar like: 43
# Komentar like: ['The concept and Ari, the manager.', 'Very lovely man running this place, he was very friendly. Ideal for a short stay.', 'This is my second stay at your property, and I would be delighted to return again in the future. The hotel is clean and comfortable, the owner and staff are very friendly, and the pricing is reasonable for the quality and service provided. I will certainly choose to stay here again next time.', 'I loved the cozy and comfortable bed with the warm blanket, which made the weather so enjoyable. The staff were very kind and welcoming. The environment and surroundings were beautiful, especially being so close to the lake—perfect for a peaceful morning stroll.', 'The location was great close to the lake and Bali Bike Park where we were riding', 'This was my second time staying at Container Smart Stay CSS, and once again, it was a fantastic experience. The host, Kadek, was incredibly welcoming and made sure we felt right at home. We also had the pleasure of meeting the owners, who are truly kind and wonderful people. The rooms were clean and comfortable, providing a perfect place to relax after a day of exploring. If you love nature, there’s plenty to do in the area. From visiting the Botanical Garden and the nearby lake to riding a scooter through the scenic hills, there’s no shortage of beautiful sights to enjoy. Highly recommend staying here, and I’ll definitely be back!', 'The place os very comfortable and is very unique.. have BBQ on request its good fpr healing from the city. Staff are very helpfull. The room is clean', 'All was good', 'Everything was great especially the staff ! They were so nice and helpful ! Thank you 😊', 'Everything was good just at night this house is very cold. (In this time in the year) Should be more blanket in the room.', 'Unique place & design. Give a new experience.', 'I had an amazing stay at Container Hotel! The unique design, modern and clean rooms, and friendly staff made for a perfect experience. The common areas were great for relaxing, and the location was convenient for exploring the city. Highly recommended!', 'The Container Smart Stay in Bali is a truly unique and innovative accommodation option. The use of shipping containers as living spaces is an original idea that promotes sustainability. The host, Kadek, is exceptionally friendly and helpful, ensuring a memorable experience for guests. The location is perfect, with nearby lakes and the beautiful botanical garden. This stay offers a refreshing change from traditional hotels, with its original concept, fantastic host, and great location.', 'The staff was very nice. It was very calm place except the evening karaoke. 😁 We enjoyed free coffee, water and tomatoes in the lobby. We liked the whole concept of staying in the container. Plus we enjoyed the option of ordering food from the local restaurant. (Good food for good money).', 'The staff and owners were very kind & helpful with whatever we needed.', 'Everything was perfect :))', 'An interesting concept. Breakfast convenient for vegetarians. Nice staff. Free coffee or tea at the reception. The room was small but nice. Parking place for car at the accommodation.', 'quiet and cozy place. good facilities. good price.', 'Great location, comfy beds, good bathroom, friendly staff, Tee and coffee facilities', 'First time staying in container was ok. Nice set up. Big bed, comfortable. Shower good, just have to wait about a minute for hot water to come through. No air con so it can warm up on hot day. Opening window for a breeze helps. Host was very nice.', 'The whole set up was fantastic, the staff were friendly and helpful, the rooms are a great layout.', 'OK, so I got to try living in a container. It was clean. Staff was super nice and helpful. Had all the basics covered.', 'Very nice outside area. The interior of the container was modern and lovely.', 'It was cheap and it was something different', 'De eigenaren hebben ons waanzinnig goed gehopen nadat we in  ...

# %% [markdown]
# ## 2. User's Country

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap user_country
'''
count_gender = df.groupby('user_country').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="user_country", 
    title="user_country",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#             user_country  jumlah
# 9              Indonesia      15
# 5                 France       8
# 3         Czech Republic       6
# 16                 Spain       4
# 0              Australia       3
# 15                Russia       3
# 11           Netherlands       3
# 6                Germany       3
# 2                 Canada       3
# 17           Switzerland       2
# 20        United Kingdom       2
# 7                Hungary       1
# 8                  India       1
# 10                 Italy       1
# 1                Austria       1
# 12           New Zealand       1
# 13              Portugal       1
# 14                 Qatar       1
# 4                Denmark       1
# 18               Tunisia       1
# 19  United Arab Emirates       1
# 21         United States       1

# %% [markdown]
# ## 3. Owner Respone

# %%
owner_df = df[df['owner_resp_text'] != 0]
owner_df = owner_df['owner_resp_text'].tolist()

print(f"Total komentar owner_resp_text: {len(owner_df)}")
print(f"Komentar owner_resp_text: {owner_df}")
# Out:
# Total komentar owner_resp_text: 28
# Komentar owner_resp_text: ['Thank you for your review and glad to know you, for your stay at CsS. Looking forward to your welcome back. Best regards CsS management', 'Thank you for your review. Special case : we will very attention to the cleanliness of the towels and beds.', 'Dear Mr. Suryadi Apologies for the late response. Glad to know that you enjoy your stay and already 2nd time here. Hope to be able to meet your satisfaction everytime you visit us. See you soon in the near future', 'Dear Jane, First of all, apol9gira for the lare response. Glad to know that you enjoy your stay for the staycation here. Hope to be able to meet your satisfactionso eevery time you go to Bedugul, you could meet us and stay with us Thank you CsS management', 'Dear John. Thank you for your perfect review, glad to know that you enjoy your stay. Looking forward to welcome you back again. Regards CsS management', 'Dear Mr. Denny Thank you so much for your review. Regards CsS management', 'Dear Mr/s Agnes Thank you for you review and we are glad to know that you have a nice experience. noted for the matrass, we will tray to improve it. Regards CsS management', "Thank you for sharing your positive experience at Container Smart Stay Bali! We're thrilled to hear that our unique concept resonated with you, and we appreciate your acknowledgment of our commitment to sustainability. It's wonderful to know that Kadek's hospitality made your stay memorable. We're glad you enjoyed our prime location near lakes and the botanical garden. Your kind words inspire us to continue providing refreshing and innovative stays. We look forward to welcoming you back for another memorable experience.", "Thank you for taking the time to share your experience with us! We're delighted to hear that you enjoyed the friendliness of our staff and the unique concept of staying in a container. We appreciate your feedback on the evening karaoke and will take it into consideration for future improvements. It's great to know that you liked the complimentary coffee, water, and tomatoes in the lobby. We're pleased you took advantage of the option to order food from the local restaurant and found it to be a good value. We look forward to welcoming you back for another enjoyable stay.", "Thank you for your kind words! We're delighted to hear that our staff and owners were able to contribute to a positive experience during your stay. It's our pleasure to assist with anything you may need. We appreciate your feedback and hope to welcome you back for another wonderful stay in the future.", "Thank you for the glowing feedback! We're thrilled to hear that everything was perfect during your stay. It's our pleasure to provide exceptional experiences, and we look forward to welcoming you back for another perfect stay in the future.", 'Thank you for your review. We are glad that overall you had a fantastic experience with us and that the staff were friendly and helpful. We apologize for the beds being a little too firm and for the noise from other guests in the recreation area. We strive to provide our guests with a comfortable, enjoyable stay and we apologize if we did not meet your expectations on this occasion.', 'Thank you for your review and your feedback. Regards CsS management', 'Dear Jan Dolezal Thank you for your review, in fact you good ask for more blanket if you felt cold. Heater is not common in Indonesia. Best regards CsS management', 'Thank you for your review and we are happy to receive your feedback.', 'Dear Mr. Komang, Thank you for your review and glad to know that you enjoy your stay. Rest assure, we will consider and think about the canopy seriously. looking forward to welcome you again regards CsS management', 'Dear Mrs. Tereza. Thank you for the review. The weather is cold because in the mountain and you never inform us that you are cold. How should we be responsible for that. An for the garbage burning it is from our neighbour, for your info, baliness now this has a proble ...

# %% [markdown]
# ## 4. Room View

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap room_view
'''
count_gender = df.groupby('room_view').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="room_view", 
    title="room_view",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#               room_view  jumlah
# 2  Superior Double Room      46
# 1  Standard Double Room      16
# 0                     0       1

# %% [markdown]
# ## 5. Stay Duration

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_duration
'''
count_gender = df.groupby('stay_duration').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="stay_duration", 
    title="stay_duration",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#   stay_duration  jumlah
# 0       1 night      38
# 1      2 nights      14
# 2      3 nights      10
# 3      8 nights       1

# %% [markdown]
# ## 6. Stay Type

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_type
'''
stay_type = df.groupby('stay_type').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(stay_type)  
plot_barplot(
    data=stay_type,
    x_col="jumlah",
    y_col="stay_type", 
    title="stay_type",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#         stay_type  jumlah
# 0          Couple      39
# 3  Solo traveller      11
# 2           Group       7
# 1          Family       6

# %% [markdown]
# ## 7. Tahun Review

# %%
# --- 1. DATA PREPARATION ---

# Pastikan kolom tanggal bertipe datetime
# Jika format tanggalmu beda (misal: "12 Dec 2023"), pandas biasanya otomatis mengenali
df['review_post_date'] = pd.to_datetime(df['review_post_date'])

# Ekstrak tahun ke kolom baru
df['year'] = df['review_post_date'].dt.year

# Hitung jumlah review per tahun dan URUTKAN BERDASARKAN TAHUN (sort_index)
# Kita pakai sort_index() agar tahunnya urut (2020, 2021, 2022...), bukan acak.
year_counts = df['year'].value_counts().sort_index()

# Konversi ke DataFrame agar mudah di-plot seaborn
year_df = year_counts.reset_index()
year_df.columns = ['tahun', 'jumlah']

# --- 2. VISUALISASI (Best Practice) ---

# plt.figure(figsize=(10, 6))

# Gunakan satu warna (misal: biru) karena ini data waktu, tidak perlu warna-warni 
# kecuali Anda ingin menghighlight tahun tertentu.
plot_barplot(
    data=year_df,
    x_col="tahun",
    y_col="jumlah", 
    title="jumlah",
    format_number="",
    x_label="tahun",
    colour_bar_set="1"
)
# year_df

# %%
df['Year'] = df['review_post_date'].dt.year

# Reset index agar 'Year' kembali menjadi kolom
rating_year = df.groupby('Year')['rating'].mean().reset_index()

# Opsional: Urutkan tahun biar rapi
rating_year = rating_year.sort_values('Year')

print(rating_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_year, 
    x_col="Year", 
    y_col="rating", 
    title="Rata-rata Rating per Tahun", 
    x_label="Tahun",
    y_label="Skor Rating",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#    Year    rating
# 0  2023  7.896552
# 1  2024  7.764706
# 2  2025  9.000000
# 3  2026  8.750000

# %%
# Filter dulu: Ambil hanya data yang 'review_text_disliked' BUKAN 0
filtered_df = df[df['review_text_disliked'] != 0]

# Baru di-grouping
dislike_by_year = filtered_df.groupby('Year')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Tahun ===")
for year, comments in dislike_by_year.items():
    print(f"Tahun {year}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per Tahun ===
# Tahun 2023: Ditemukan 13 komentar dislike.
# ['The room was a bit humid - it seemed to us that air ventilation in the room did not work properly.', 'you can improve the bathroom. use the small low bathtub to avoid corrosion on the container body. use thin insulation to make the room more warm during night or morning', 'It would be nice to have an option for breakfast', 'Wifi was slightly slow. Tv was a bit difficult to use. Otherwise nice stay', 'Beds a little firm and a little noisy with the other guests having fun in the recreation area.', 'It had a bad smell,the bathroom Is mouldy and does not drain water properly,There was no shower holder.The location is hard to find a taxi', 'Контейнеры имеют металлические козырьки, которые при ветре очень шумят. Если у вас есть беруши - возьмите, они могут понадобиться. Днём жарко в номере, но достаточно открыть окна и двери, но мы особо днём не сидели в номере - рядом есть места, где можно провести весь день. Вечером холодно - одеяла вас конечно согреют, но лучше берите с собой теплые вещи. Ну и номер тесноват, однако для задачи - переночевать день, два - самый раз.', 'Mitten im Nichts, irgendwo an einem brüchigen Feldweg. Leider hatte es an dem Tag ein paar Stunden geregnet, und es war einfach alles feucht und klamm, ohne jemals wieder trocken zu werden', 'Le lenzuola non erano perfettamente pulite e il bagno era molto umido.', 'Die Dusche war sehr ekelhaft. Generell war es aufgrund der mangelnden Isolierung sehr kalt, wodurch wir uns erkältet hatten. Wir hatten über die Unterkunft einen Roller gemietet. Im Vergleich zu anderen Orten war es sehr teuer. Die wollten 150k pro Tag. Des Weiteren mussten wir feststellen, dass eine der Bremsen des Rollers während der Fahrt versagt hat. Zum Glück ist nichts passiert, aber es hätte schlimm für uns enden können.', "Les nuits sont froides et l'eau de la douche n'est pas chaude longtemps Les enfants font du bruit tard", 'ne parle pas anglais', 'Schimmel, laut in der Nacht, Kalt in der Nacht, heiss am Tag. Dies ist auch aufgrund der Lage im Norden. Man ist ziemlich abgelegen, ohne eigenes Motorrad oder Auto sehr schwierig herum zukommen, Taxis sehr teuer und keine Grabs']
# ------------------------------
# Tahun 2024: Ditemukan 7 komentar dislike.
# ['Nothing', 'The mattress was almost inexistent', 'It start to getting rusty.', 'Nothing. All perfect!', 'Be aware of the fact that it can get very cold during the evening and night (1st half of Sep). Be ready to put some extra clothes on for sleeping. There is no heater available.', 'Très humide il fait assez froid dans les container (mais il avait plu) Pas de wifi qui marchait et compliqué l’eau chaude Rien du tout autour pour manger, prévoir un véhicule', 'La salle de bain rouillé et les tâches dans les draps - acces defonce']
# ------------------------------
# Tahun 2025: Ditemukan 9 komentar dislike.
# ['Nothing', 'Nothing at all, I liked everything.', '-', 'Not cosy. Very basic white interior withing metal container walls with cold white lights on the ceiling. We arrived on a cold rainy night. Without A/C or any metal wall insulation it was pretty hard to warm up. Hot water in the shower was also misbehaving.', 'Atap kanopi sedikit berisik kalau kena angin, mungkin perlu sedikit perbaikan.', 'Na ubytování je zima tak se na to pripravte. Je to způsobené ale počasím. Majitel za to nemůže Co nám vadilo je neustálý smrad pálení odpadků od sousedního domu.', "Petit déjeuner ; uniquement nasi goreng ou mie goreng livrés à l'hôtel Le froid et l'humidité la nuit Calme mais loin des commerces et restaurants", 'Logement humide. Manque un système de déshumidificateur ou chauffage pour contrer ce problème', 'Leider war das Wasser beim Duschen eher nur knapp warm. Da es an diesem Tag viel geregt hat und bewölkt war, wäre eine heisse dusche schön gewesen. Bei schönem Wetter oder in der trocken Saison bestimmt weniger ein Problem.']
# ------------------------------
# Tahun 2026: Ditemukan 2 komentar dislike.
# ['Towels and bedding could have been a bit cleaner.', 'Nothing']
# ------------------------------

# %%
# Filter dulu: Ambil hanya data yang 'review_text_disliked' BUKAN 0
filtered_df = df[df['review_text_liked'] != 0].copy()

# Baru di-grouping
dislike_by_year = filtered_df.groupby('Year')['review_text_liked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik like per Tahun ===")
for year, comments in dislike_by_year.items():
    print(f"Tahun {year}: Ditemukan {len(comments)} komentar like.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik like per Tahun ===
# Tahun 2023: Ditemukan 18 komentar like.
# ['The Container Smart Stay in Bali is a truly unique and innovative accommodation option. The use of shipping containers as living spaces is an original idea that promotes sustainability. The host, Kadek, is exceptionally friendly and helpful, ensuring a memorable experience for guests. The location is perfect, with nearby lakes and the beautiful botanical garden. This stay offers a refreshing change from traditional hotels, with its original concept, fantastic host, and great location.', 'The staff was very nice. It was very calm place except the evening karaoke. 😁 We enjoyed free coffee, water and tomatoes in the lobby. We liked the whole concept of staying in the container. Plus we enjoyed the option of ordering food from the local restaurant. (Good food for good money).', 'The staff and owners were very kind & helpful with whatever we needed.', 'Everything was perfect :))', 'An interesting concept. Breakfast convenient for vegetarians. Nice staff. Free coffee or tea at the reception. The room was small but nice. Parking place for car at the accommodation.', 'quiet and cozy place. good facilities. good price.', 'Great location, comfy beds, good bathroom, friendly staff, Tee and coffee facilities', 'First time staying in container was ok. Nice set up. Big bed, comfortable. Shower good, just have to wait about a minute for hot water to come through. No air con so it can warm up on hot day. Opening window for a breeze helps. Host was very nice.', 'The whole set up was fantastic, the staff were friendly and helpful, the rooms are a great layout.', 'It was cheap and it was something different', 'Alles sehr sauber. Personal sehr freundlich und hilfsbereit. Ruhige Lage, bequemes Bett. Hatten schöne Aussicht vom oberen Container', 'Отличный комплекс, чтобы провести выходные в горах. Номера свежие - отелю год, внутри все чисто, убрано. Постельное белье тоже чистое, белоснежное, что не всегда бывает в номерах данного ценового диапазона. Месторасположение хорошее - тихо, рядом озеро, можно погулять вдоль него. В номер можно заказывать еду, у них есть меню - заказываешь сотрудникам, они звонят, заказывают и приносят. На лобби можно брать кофе, чай, горячий шоколад и лапшу - очень согревает вечерами. Сотрудники очень любезные, дружелюбные, поддерживают беседу.', 'Cooles Konzept', "La struttura si presenta bene all'estero, con I containers tutti colorati e lo staff disponibile e accogliente. Va bene per una sola notte di passaggio.", 'Das Personal war sehr lieb und hat bei Fragen oder Anmerkungen direkt geholfen.', 'Le design du container, le lit et son matelas, la situation géographique excellente', 'personnel concerné', 'Grosse Betten, nette Leute, schöne Wohnatmosphäre in der Natur, wenig touristisch']
# ------------------------------
# Tahun 2024: Ditemukan 11 komentar like.
# ['The place os very comfortable and is very unique.. have BBQ on request its good fpr healing from the city. Staff are very helpfull. The room is clean', 'All was good', 'Everything was great especially the staff ! They were so nice and helpful ! Thank you 😊', 'Everything was good just at night this house is very cold. (In this time in the year) Should be more blanket in the room.', 'Unique place & design. Give a new experience.', 'I had an amazing stay at Container Hotel! The unique design, modern and clean rooms, and friendly staff made for a perfect experience. The common areas were great for relaxing, and the location was convenient for exploring the city. Highly recommended!', 'Very nice outside area. The interior of the container was modern and lovely.', 'L’hôte est accommodant malgré la barrière de la langue. Atypique pour une nuit', 'Hem passat fred a la nit i hi havien goteres, no plovia. Massa lluny del centre.', 'Froid et humide', 'L originalité']
# ------------------------------
# Tahun 2025: Ditemukan 11 komentar like.
# ['The concept and Ari, the manager.', 'This is my second stay at your property, and I would be delighted to return again in the future. The hotel is clean and comfortable, the owner and staff are very friendly, and the pricing is reasonable for the quality and service provided. I will certainly choose to stay here again next time.', 'I loved the cozy and comfortable bed with the warm blanket, which made the weather so enjoyable. The staff were very kind and welcoming. The environment and surroundings were beautiful, especially being so close to the lake—perfect for a peaceful morning stroll.', 'The location was great close to the lake and Bali Bike Park where we were riding', 'This was my second time staying at Container Smart Stay CSS, and once again, it was a fantastic experience. The host, Kadek, was incredibly welcoming and made sure we felt right at home. We also had the pleasure of meeting the owners, who are truly kind and wonderful people. The rooms were clean and comfortable, providing a perfect place to relax after a day of exploring. If you love nature, there’s plenty to do in the area. From visiting the Botanical Garden and the nearby lake to riding a scooter through the scenic hills, there’s no shortage of beautiful sights to enjoy. Highly recommend staying here, and I’ll definitely be back!', 'OK, so I got to try living in a container. It was clean. Staff was super nice and helpful. Had all the basics covered.', 'Kamar bersih, staf yg ramah dan sgt membantu', 'Ubytování je krásné, na 2 noci ideální', "Le cadre et la gentillesse du jeune homme de l'accueil", "Très représentatif de l'annonce. Personnelle a l'écoute et souriant. Extérieur, intérieur Propre et en bien entretenu.", 'Die Idee ist super mit den Containern. Auch der nachhaltige Gedanke. Das Frühstück ist eigentlich erst ab 08:00 Uhr. Wir konnten es jedoch um 07:00 bestellen da wir um 08:00 im Bali Bike Park gebucht hatten. Es gibt rund um die Uhr gratis Kaffee und Tee in der Lobby.']
# ------------------------------
# Tahun 2026: Ditemukan 3 komentar like.
# ['Very lovely man running this place, he was very friendly. Ideal for a short stay.', 'De eigenaren hebben ons waanzinnig goed gehopen nadat we in het ziekenhuis waren beland. Ze hebben echt alles voor ons geregeld.', 'Pelayanannya ramah']
# ------------------------------

# %%
# Reset index agar 'Year' kembali menjadi kolom
rating_room_year = filtered_df.groupby('room_view')['rating'].mean().reset_index()

rating_room_year = rating_room_year[rating_room_year!= 0]

# Opsional: Urutkan tahun biar rapi
rating_room_year = rating_room_year.sort_values('rating')

print(rating_room_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_room_year , 
    x_col="rating", 
    y_col="room_view", 
    title="Rata-rata Rating per room_view", 
    x_label="Skor Rating",
    y_label="Room View",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#               room_view    rating
# 0                   NaN  7.000000
# 2  Superior Double Room  8.096774
# 1  Standard Double Room  8.454545
# /tmp/ipykernel_9091/1757560589.py:27: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   barplot = sns.barplot(

# %%
filtered_df = df[df['review_text_disliked'] != 0].copy()
# Baru di-grouping
dislike_by_room_view = filtered_df.groupby('room_view')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Kamar ===")
for room_view, comments in dislike_by_room_view.items():
    print(f"Pada {room_view}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per Kamar ===
# Pada 0: Ditemukan 1 komentar dislike.
# ['Schimmel, laut in der Nacht, Kalt in der Nacht, heiss am Tag. Dies ist auch aufgrund der Lage im Norden. Man ist ziemlich abgelegen, ohne eigenes Motorrad oder Auto sehr schwierig herum zukommen, Taxis sehr teuer und keine Grabs']
# ------------------------------
# Pada Standard Double Room: Ditemukan 7 komentar dislike.
# ['Nothing at all, I liked everything.', 'Nothing. All perfect!', 'It would be nice to have an option for breakfast', 'Atap kanopi sedikit berisik kalau kena angin, mungkin perlu sedikit perbaikan.', "Petit déjeuner ; uniquement nasi goreng ou mie goreng livrés à l'hôtel Le froid et l'humidité la nuit Calme mais loin des commerces et restaurants", 'Logement humide. Manque un système de déshumidificateur ou chauffage pour contrer ce problème', 'Très humide il fait assez froid dans les container (mais il avait plu) Pas de wifi qui marchait et compliqué l’eau chaude Rien du tout autour pour manger, prévoir un véhicule']
# ------------------------------
# Pada Superior Double Room: Ditemukan 23 komentar dislike.
# ['Towels and bedding could have been a bit cleaner.', 'Nothing', '-', 'Nothing', 'The mattress was almost inexistent', 'It start to getting rusty.', 'The room was a bit humid - it seemed to us that air ventilation in the room did not work properly.', 'you can improve the bathroom. use the small low bathtub to avoid corrosion on the container body. use thin insulation to make the room more warm during night or morning', 'Wifi was slightly slow. Tv was a bit difficult to use. Otherwise nice stay', 'Beds a little firm and a little noisy with the other guests having fun in the recreation area.', 'Not cosy. Very basic white interior withing metal container walls with cold white lights on the ceiling. We arrived on a cold rainy night. Without A/C or any metal wall insulation it was pretty hard to warm up. Hot water in the shower was also misbehaving.', 'Be aware of the fact that it can get very cold during the evening and night (1st half of Sep). Be ready to put some extra clothes on for sleeping. There is no heater available.', 'It had a bad smell,the bathroom Is mouldy and does not drain water properly,There was no shower holder.The location is hard to find a taxi', 'Nothing', 'Na ubytování je zima tak se na to pripravte. Je to způsobené ale počasím. Majitel za to nemůže Co nám vadilo je neustálý smrad pálení odpadků od sousedního domu.', 'Контейнеры имеют металлические козырьки, которые при ветре очень шумят. Если у вас есть беруши - возьмите, они могут понадобиться. Днём жарко в номере, но достаточно открыть окна и двери, но мы особо днём не сидели в номере - рядом есть места, где можно провести весь день. Вечером холодно - одеяла вас конечно согреют, но лучше берите с собой теплые вещи. Ну и номер тесноват, однако для задачи - переночевать день, два - самый раз.', 'Leider war das Wasser beim Duschen eher nur knapp warm. Da es an diesem Tag viel geregt hat und bewölkt war, wäre eine heisse dusche schön gewesen. Bei schönem Wetter oder in der trocken Saison bestimmt weniger ein Problem.', 'La salle de bain rouillé et les tâches dans les draps - acces defonce', 'Mitten im Nichts, irgendwo an einem brüchigen Feldweg. Leider hatte es an dem Tag ein paar Stunden geregnet, und es war einfach alles feucht und klamm, ohne jemals wieder trocken zu werden', 'Le lenzuola non erano perfettamente pulite e il bagno era molto umido.', 'Die Dusche war sehr ekelhaft. Generell war es aufgrund der mangelnden Isolierung sehr kalt, wodurch wir uns erkältet hatten. Wir hatten über die Unterkunft einen Roller gemietet. Im Vergleich zu anderen Orten war es sehr teuer. Die wollten 150k pro Tag. Des Weiteren mussten wir feststellen, dass eine der Bremsen des Rollers während der Fahrt versagt hat. Zum Glück ist nichts passiert, aber es hätte schlimm für uns enden können.', "Les nuits sont froides et l'eau de la douche n'est pas chaude longtemps Les enfants font du bruit tard", 'ne parle pas anglais']
# ------------------------------

# %%
sns.lineplot(data=df, x='review_post_date', y='rating')
# Out:
# <Axes: xlabel='review_post_date', ylabel='rating'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
# Out:
# /tmp/ipykernel_9091/2148740873.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.set_index(date_col).resample('M').size()
# review_post_date
# 2023-08-31    8
# 2023-09-30    5
# 2023-11-30    5
# 2024-07-31    4
# 2023-07-31    4
# 2023-10-31    3
# 2025-09-30    3
# 2024-10-31    3
# 2024-11-30    2
# 2025-10-31    2
# 2025-08-31    2
# 2025-06-30    2
# 2023-06-30    2
# 2026-05-31    2
# 2024-05-31    2
# 2024-06-30    1
# 2025-05-31    1
# 2026-03-31    1
# 2026-01-31    1
# 2025-11-30    1
# 2023-12-31    1
# 2024-08-31    1
# 2024-03-31    1
# 2025-03-31    1
# 2025-01-31    1
# 2024-12-31    1
# 2024-04-30    1
# 2024-09-30    1
# 2023-05-31    1
# 2025-04-30    0
# 2025-02-28    0
# 2025-07-31    0
# 2024-02-29    0
# 2024-01-31    0
# 2025-12-31    0
# 2026-02-28    0
# 2026-04-30    0
# dtype: int64

# %%
import pandas as pd

# 1. Pastikan kolom target sudah format datetime
col_name = 'review_post_date'  # Sesuaikan nama kolom tanggal Anda
df[col_name] = pd.to_datetime(df[col_name], errors='coerce')

# 2. Urutan bulan yang benar (agar tidak terurut abjad April duluan)
bulan_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 
    'July', 'August', 'September', 'October', 'November', 'December'
]

# 3. Ambil nama bulan dan hitung
# dt.month_name() mengambil nama bulan (Jan, Feb, dst) mengabaikan tahun
monthly_counts = df[col_name].dt.month_name().value_counts()

# 4. Urutkan hasil sesuai kalender (bukan jumlah terbanyak)
monthly_counts = monthly_counts.reindex(bulan_order, fill_value=0)

# 5. Tampilkan Hasil
print("--- Total Data Per Bulan (Akumulasi Semua Tahun) ---")
print(monthly_counts.sort_values(ascending=False))

# --- Opsional: Tampilkan dalam Grafik Batang ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
monthly_counts.plot(kind='bar', color='teal')
plt.title('Total Review Berdasarkan Bulan (Musiman)')
plt.xlabel('Bulan')
plt.ylabel('Total Jumlah Review')
plt.xticks(rotation=45)
plt.show()
# Out:
# --- Total Data Per Bulan (Akumulasi Semua Tahun) ---
# review_post_date
# August       11
# September     9
# July          8
# October       8
# November      8
# May           6
# June          5
# March         3
# January       2
# December      2
# April         1
# February      0
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
# Out:
# /tmp/ipykernel_9091/2148740873.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.set_index(date_col).resample('M').size()
# review_post_date
# 2023-08-31    8
# 2023-09-30    5
# 2023-11-30    5
# 2024-07-31    4
# 2023-07-31    4
# 2023-10-31    3
# 2025-09-30    3
# 2024-10-31    3
# 2024-11-30    2
# 2025-10-31    2
# 2025-08-31    2
# 2025-06-30    2
# 2023-06-30    2
# 2026-05-31    2
# 2024-05-31    2
# 2024-06-30    1
# 2025-05-31    1
# 2026-03-31    1
# 2026-01-31    1
# 2025-11-30    1
# 2023-12-31    1
# 2024-08-31    1
# 2024-03-31    1
# 2025-03-31    1
# 2025-01-31    1
# 2024-12-31    1
# 2024-04-30    1
# 2024-09-30    1
# 2023-05-31    1
# 2025-04-30    0
# 2025-02-28    0
# 2025-07-31    0
# 2024-02-29    0
# 2024-01-31    0
# 2025-12-31    0
# 2026-02-28    0
# 2026-04-30    0
# dtype: int64
