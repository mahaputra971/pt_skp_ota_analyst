# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/mahaputra971/pt_skp/output/pondok-pitaya_2025_12_08_13_15_06/reviews_most_relevant.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              257 non-null    object
#  1   user_country          257 non-null    object
#  2   room_view             251 non-null    object
#  3   stay_duration         257 non-null    object
#  4   stay_type             257 non-null    object
#  5   review_post_date      257 non-null    object
#  6   review_title          256 non-null    object
#  7   rating                257 non-null    float64
#  8   original_lang         257 non-null    object
#  9   review_text_liked     157 non-null    object
#  10  review_text_disliked  119 non-null    object
#  11  full_review           257 non-null    object
#  12  en_full_review        189 non-null    object
#  13  found_helpful         257 non-null    int64
#  14  found_unhelpful       257 non-null    int64
#  15  owner_resp_text       4 non-null      object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 32.2+ KB

# %%
df.head()
# Out:
#   username    user_country                         room_view stay_duration  \
# 0    Emily  United Kingdom                 One-Bedroom Suite      7 nights
# 1     Mark       Australia                 One-Bedroom Suite      6 nights
# 2      Kim       Australia  Standard Twin Room with Sea View       1 night
# 3    Karen       Australia                 One-Bedroom Suite      4 nights
# 4    Heidi       Australia                 One-Bedroom Suite      2 nights
#
#   stay_type     review_post_date  \
# 0    Family  08-25-2024 00:00:00
# 1    Family  11-17-2025 00:00:00
# 2    Couple  11-15-2025 00:00:00
# 3    Couple  10-31-2025 00:00:00
# 4    Couple  10-29-2025 00:00:00
#
#                                         review_title  rating original_lang  \
# 0                                        Exceptional    10.0            en
# 1                                               Good     7.0            en
# 2                                          Very good     8.0            en
# 3  Right on the beach, good breezes, air con in r...     8.0            en
# 4                                             Superb     9.0            en
#
#                                    review_text_liked  \
# 0  The staff are fantastic and the food is delici...
# 1  Location right on the beach, asked for a fridg...
# 2   Amazing location good facilities And great staff
# 3  The property is on the beach and is large. It ...
# 4  Our stay at Pondok Pitaya Balian Hotel was gre...
#
#                                 review_text_disliked  \
# 0                                                NaN
# 1                            Hotel a little run down
# 2                 Small fridge in room would be good
# 3  Nothing, it could do with a strong water press...
# 4                                                NaN
#
#                                          full_review  \
# 0  title: Exceptional. liked: The staff are fanta...
# 1  title: Good. liked: Location right on the beac...
# 2  title: Very good. liked: Amazing location good...
# 3  title: Right on the beach, good breezes, air c...
# 4  title: Superb. liked: Our stay at Pondok Pitay...
#
#                                       en_full_review  found_helpful  \
# 0  title: Exceptional. liked: The staff are fanta...              0
# 1  title: Good. liked: Location right on the beac...              0
# 2  title: Very good. liked: Amazing location good...              0
# 3  title: Right on the beach, good breezes, air c...              0
# 4  title: Superb. liked: Our stay at Pondok Pitay...              0
#
#    found_unhelpful                                    owner_resp_text
# 0                0                                                NaN
# 1                0  Dear Mark Thank you for your review, We will u...
# 2                0  Dear Kim Thank you for your review We're glad ...
# 3                0  Dear Karen Thank you so much for your kind rev...
# 4                0  Dear Heidi Thank you for your kind review. we'...

# %%
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              257 non-null    object
#  1   user_country          257 non-null    object
#  2   room_view             257 non-null    object
#  3   stay_duration         257 non-null    object
#  4   stay_type             257 non-null    object
#  5   review_post_date      257 non-null    object
#  6   review_title          257 non-null    object
#  7   rating                257 non-null    float64
#  8   original_lang         257 non-null    object
#  9   review_text_liked     257 non-null    object
#  10  review_text_disliked  257 non-null    object
#  11  full_review           257 non-null    object
#  12  en_full_review        257 non-null    object
#  13  found_helpful         257 non-null    int64
#  14  found_unhelpful       257 non-null    int64
#  15  owner_resp_text       257 non-null    object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 32.2+ KB

# %%
df.head()
# Out:
#   username    user_country                         room_view stay_duration  \
# 0    Emily  United Kingdom                 One-Bedroom Suite      7 nights
# 1     Mark       Australia                 One-Bedroom Suite      6 nights
# 2      Kim       Australia  Standard Twin Room with Sea View       1 night
# 3    Karen       Australia                 One-Bedroom Suite      4 nights
# 4    Heidi       Australia                 One-Bedroom Suite      2 nights
#
#   stay_type     review_post_date  \
# 0    Family  08-25-2024 00:00:00
# 1    Family  11-17-2025 00:00:00
# 2    Couple  11-15-2025 00:00:00
# 3    Couple  10-31-2025 00:00:00
# 4    Couple  10-29-2025 00:00:00
#
#                                         review_title  rating original_lang  \
# 0                                        Exceptional    10.0            en
# 1                                               Good     7.0            en
# 2                                          Very good     8.0            en
# 3  Right on the beach, good breezes, air con in r...     8.0            en
# 4                                             Superb     9.0            en
#
#                                    review_text_liked  \
# 0  The staff are fantastic and the food is delici...
# 1  Location right on the beach, asked for a fridg...
# 2   Amazing location good facilities And great staff
# 3  The property is on the beach and is large. It ...
# 4  Our stay at Pondok Pitaya Balian Hotel was gre...
#
#                                 review_text_disliked  \
# 0                                                  0
# 1                            Hotel a little run down
# 2                 Small fridge in room would be good
# 3  Nothing, it could do with a strong water press...
# 4                                                  0
#
#                                          full_review  \
# 0  title: Exceptional. liked: The staff are fanta...
# 1  title: Good. liked: Location right on the beac...
# 2  title: Very good. liked: Amazing location good...
# 3  title: Right on the beach, good breezes, air c...
# 4  title: Superb. liked: Our stay at Pondok Pitay...
#
#                                       en_full_review  found_helpful  \
# 0  title: Exceptional. liked: The staff are fanta...              0
# 1  title: Good. liked: Location right on the beac...              0
# 2  title: Very good. liked: Amazing location good...              0
# 3  title: Right on the beach, good breezes, air c...              0
# 4  title: Superb. liked: Our stay at Pondok Pitay...              0
#
#    found_unhelpful                                    owner_resp_text
# 0                0                                                  0
# 1                0  Dear Mark Thank you for your review, We will u...
# 2                0  Dear Kim Thank you for your review We're glad ...
# 3                0  Dear Karen Thank you so much for your kind rev...
# 4                0  Dear Heidi Thank you for your kind review. we'...

# %%
def plot_barplot(data, x_col, y_col, title="", format_number="", x_label="", y_label="", colour_bar_set="3"):
    plt.figure(figsize=(10, max(6, len(data) * 0.4))) # Tinggi otomatis menyesuaikan banyaknya negara

    # --- 1. DETEKSI OTOMATIS: VERTIKAL ATAU HORIZONTAL? ---
    # Jika Y-nya angka, berarti Vertikal. Jika Y-nya teks, berarti Horizontal.
    if pd.api.types.is_numeric_dtype(data[y_col]):
        orientation = 'vertical'
        color_basis = data[y_col] # Warna ikut tinggi Y
    else:
        orientation = 'horizontal'
        color_basis = data[x_col] # Warna ikut panjang X (Jumlah)

    # --- 2. LOGIKA WARNA ---
    if colour_bar_set == "1": # Tinggi=Hijau
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    elif colour_bar_set == "2": # Tinggi=Merah
        norm = plt.Normalize(color_basis.min(), color_basis.max())
        sm = plt.cm.ScalarMappable(cmap="RdYlGn_r", norm=norm)
        colors = [sm.to_rgba(val) for val in color_basis]
    else: # Mode 3 (Default Biru - Aman untuk Kategori)
        colors = ["#4c72b0"] * len(data)
        sm = None

    # --- 3. MEMBUAT PLOT ---
    barplot = sns.barplot(
        x=x_col, 
        y=y_col,
        data=data,
        palette=colors,
        hue=y_col if orientation == 'horizontal' else x_col, # Fix warning seaborn baru
        legend=False
    )

    # --- 4. MEMBERI LABEL ANGKA (SMART POSITIONING) ---
    for bar in barplot.patches:
        # Ambil dimensi batang
        width = bar.get_width()
        height = bar.get_height()
        
        # Tentukan nilai yang akan ditulis
        value = width if orientation == 'horizontal' else height
        if np.isnan(value): continue

        # Format label
        if isinstance(value, float):
            label_text = f"{format_number}{value:.2f}"
            if value.is_integer(): label_text = f"{format_number}{int(value)}"
        else:
            label_text = f"{format_number}{int(value)}"

        # Tentukan posisi teks
        if orientation == 'horizontal':
            # Jika horizontal, teks ditaruh di sebelah kanan ujung batang
            text_x = width + (data[x_col].max() * 0.01) # Beri sedikit jarak
            text_y = bar.get_y() + height / 2
            ha_align = 'left'
            color_text = 'black' # Teks hitam biar terbaca di background putih
        else:
            # Jika vertikal, teks ditaruh di tengah/atas batang
            text_x = bar.get_x() + width / 2
            text_y = bar.get_y() + height / 2
            ha_align = 'center'
            color_text = 'white'

        plt.text(
            text_x, 
            text_y, 
            label_text, 
            va='center', 
            ha=ha_align, 
            fontsize=10, 
            color=color_text, 
            weight='bold'
        )

    # Kosmetik
    plt.title(title, loc="center", fontsize=16, fontweight='bold', pad=20)
    plt.xlabel(x_label if x_label else x_col, fontsize=12)
    plt.ylabel(y_label if y_label else y_col, fontsize=12)
    
    if orientation == 'vertical':
        plt.grid(axis='y', linestyle='--', alpha=0.3)
    else:
        plt.grid(axis='x', linestyle='--', alpha=0.3) # Grid X untuk horizontal

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 1. Rating User

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap rating
'''
count_gender = df.groupby('rating').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="rating",
    y_col="jumlah", 
    title="rating",
    format_number="",
    x_label="Banyak",
    colour_bar_set="2"
)
# Out:
#    rating  jumlah
# 7     8.0      72
# 9    10.0      67
# 8     9.0      49
# 6     7.0      32
# 5     6.0      14
# 4     5.0       8
# 2     3.0       6
# 0     1.0       5
# 1     2.0       3
# 3     4.0       1

# %%
dislike_df = df[df['review_text_disliked'] != 0]
dislike_list = dislike_df['review_text_disliked'].tolist()

print(f"Total komentar dislike: {len(dislike_list)}")
print(f"Komentar dislike: {dislike_list}")
# Out:
# Total komentar dislike: 119
# Komentar dislike: ['Hotel a little run down', 'Small fridge in room would be good', 'Nothing, it could do with a strong water pressure over all the outdoor paths and stones to bring it back that’s all. It was all lovely. Great breakfast included too!', 'Needs minor repairs/ maintenance, but didn’t really bother me', 'Bugs', 'Would have been nice to have fruit included in breakfast as I don’t eat ebggs', 'I had an overnight stay and it suited me well however there was a lot of light first thing in the morning (which suits if you are after an early surf).', 'The food could be', 'The bathrooms in the rooms need to be updated as were a bit small and quite tired. Also could maintain the access to the beach a lot better as there was a lot of logs and some rubbish straight out in front which made access not the easiest and would be simple to clean up.', 'No fridge in room s', 'One of the toilets leaked and was a bit smelly which will need to be fixed.', 'It needs a couple of minor things like a fridge in the room and mosquito netting. The restaurant staff need to be better trained in customer service as they stand around talking unless you specifically call them over. The rooms are very basic but functional.', 'No TV. Not that it was a big problem for us though.', 'The pool needs an upgrade but still clean & nice.', 'The (tap) water smelled like it came straight from the adjacent river... Otherwise no complaints', 'Pool is a bit dated but great views of the ocean', "Breakfast doesn't start until 8am", 'No fridge or tv in room', 'Would have been nice to have a refrigerator in the room or at least a communal refrigerator to store drinks etc. Also the sliding door to the bathroom was very difficult to move.', 'The location is quite isolated from the main tourist area so long drives were needed to visit anywhere. The beach is more suitable for surfing than swimming with a strong riptide. When they ran out of coconuts on our second day they didn’t restock which was annoying.', 'One thing that could be improved is the music in the café. It would be great to hear something more traditional or calm and chill, rather than loud pop tracks that don’t quite match the vibe of the place. The only other downside is the price, which feels about 20% higher than expected, especially with cheaper options nearby. Still, I return every time because this place has become a meaningful part of my Bali experience.', 'No bottled water in the restaurant.', '. Had trouble in room with wifi connection, but wifi was good at the restaurant.', 'Some mosquitos still can get into rooms even with doors shut.', 'The mattress was too firm', 'Some facilities could use a revamp.', 'Mosquitoes in my room and no nets.', 'Uncomfortable hard bed, only 2 pillows. Breakfast very average, menu needs upgrade. Need to stock soy or oat milk. No avocado or oats on offer. Coffee not so great. Outside bathroom. Not so clean. View of sea through the bathroom. Pool old and not maintained. The rubbish out the front of resort needs to be cleaned up. No fridge in room. No tv in room. More like 3 star not 4 star. Dogs in the area fighting.', 'Location', 'The bathroom (which was semi outside) was cute, but smelt musty and toilet also smelt sometimes..', "Obviously a surfing spot. didn't enjoy beach. Black sand and quite rough under foot", 'No fudge in room.', 'Beds were extremely firm and no bar fridge to keep drinks cold', 'The wifi reception didn’t work in our room & the outdoor bathroom sounded nice but meant there were lots of insects coming in at night when the light was on. Not a big deal to us but probably not for everyone.', 'Pool water quality was not maintained', 'Pool needs a bit of work', 'Bed was extra extra firm with only one pillow each. Bathroom on the balcony is ok if you are a guy otherwise the neighbours and people walking by can get an eye full as walls only waist high.', "wifi was not great unless you stood right next to the router. But also then it wasn't very good. Pil ...

# %%
like_df = df[df['review_text_liked'] != 0]
like_list = like_df['review_text_liked'].tolist()

print(f"Total komentar like: {len(like_list)}")
print(f"Komentar like: {like_list}")
# Out:
# Total komentar like: 157
# Komentar like: ['The staff are fantastic and the food is delicious. Ideal surf spot and hidden away gem to get a real local feel.', 'Location right on the beach, asked for a fridge and they brought us one within an hour', 'Amazing location good facilities And great staff', 'The property is on the beach and is large. It has everything you need. I liked the massage here, better than the other one in the street, and the views of the surf. We were watching the surfers all the time and my hubby had a great time surfing. Also loved Nikki’s yoga classes up the road, strong but fantastic too. We had a relaxing stay overall.', 'Our stay at Pondok Pitaya Balian Hotel was great, it is a beach front hotel with great views of the surf break from the restaurant, pool or gardens. Our room was situated on the 2nd level with limited views from the open bathroom of the beach/break but was still comfortable and clean. The staff were warm and friendly and the breakfast options were tasty and freshly made.', 'Location and the space around the property. It was relaxing and quiet. I had one of the separate bungalows at the front and could check the surf from my front door.', 'Great location', 'Fabulous beachfront location. Comprehensive menu at restaurant. Spa treatments available. Room was rustic but clean and comfortable with outdoor bathroom. Swimming pool and ocean view room.', 'Fantastic place to stay right in front of shipwrecks surf break', 'Beautiful and peaceful.', 'Perfect location.', 'Great location', 'Fantastic location right on the beach with views to the surf break from the pool and restaurant. Rooms were very cute Balinese style and grounds were well maintained and the staff very attentive and friendly. Short walk to several other warungs and restaurants.', 'Location', "Beautiful location. Quite out of the way tho. 3 to 4 hours from Denpasar airport. Came here because my husband surfs and kite surfs. I don't think you'd come here as a destination unless you're a surfer. The sand is black and rocky. I didn't swim at the beach, just the pool. There are no shops or cafes anywhere close. You'd need transport to take you into the nearest town, but that didn't worry us as we weren't after that kind of trip, and were very happy to stay put in the hotel the whole time, just relaxing and unwinding from our busy lives. We both practise Yoga and there are 2 lovely Yoga shalas. One overlooking the beach, the other nestled in the garden area around the back. We stayed in one of the house/bungalows. We had A/C, a fridge and a kettle. Some rooms do not have this so if that's important to you make sure your room has this. Those 3 are deal breakers for us. There are also a whole set of basic rooms, and a few other types of rooms which some travellers may be totally fine with. Just depends on what you're after. Look into it before you book so you know what to expect from your room. The staff are friendly and such warm people. The food at the restaurant is great. Generous breakfast was included. If you order food at the restaurant, it takes a while to come out but that didn't bother us at all, being on a holiday and not in a rush. Gave us time to sit, read, talk and chill. Other guests are friendly, nice people, rather than the posey, loud, drunk vibe you might get at busier resorts down south. The rooms are made up and cleaned beautifully. We had 2 bathrooms. One of the toilets leaked and was a bit smelly which will need to be fixed. Daily yoga is fantastic, the teacher was brilliant and a beautiful friendly person. We will come back, hopefully next year.", 'Location is excellent , staff were very friendly', 'It’s right on the beach. Great for surfers. It’s at the end of a road so very little traffic to contend with. Traditional Balinese type rooms with beautiful gardens.', 'Perfect location for surfing Balian. Great for young families or couples looking for a quiet Bali paradise.', 'Beach front. Very romantic little villa. Food was nice. Walking dista ...

# %% [markdown]
# ## 2. User's Country

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap user_country
'''
count_gender = df.groupby('user_country').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="user_country", 
    title="user_country",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#             user_country  jumlah
# 1              Australia     120
# 11               Germany      15
# 10                France      14
# 20           New Zealand      13
# 14             Indonesia      12
# 34         United States      11
# 33        United Kingdom      11
# 18           Netherlands       9
# 30           Switzerland       7
# 17                 Japan       5
# 25                Russia       3
# 16                 Italy       3
# 29                Sweden       3
# 28                 Spain       3
# 9                Finland       2
# 12             Hong Kong       2
# 13                 India       2
# 7                Denmark       2
# 32  United Arab Emirates       2
# 27          South Africa       2
# 23                Poland       2
# 2                Austria       1
# 31                Taiwan       1
# 3                 Brazil       1
# 26              Slovenia       1
# 22                  Peru       1
# 24              Portugal       1
# 8                Ecuador       1
# 21      Papua New Guinea       1
# 4      Brunei Darussalam       1
# 19         New Caledonia       1
# 5                 Canada       1
# 6         Czech Republic       1
# 15               Ireland       1
# 0              Argentina       1

# %% [markdown]
# ## 3. Owner Respone

# %%
owner_df = df[df['owner_resp_text'] != 0]
owner_df = owner_df['owner_resp_text'].tolist()

print(f"Total komentar owner_resp_text: {len(owner_df)}")
print(f"Komentar owner_resp_text: {owner_df}")
# Out:
# Total komentar owner_resp_text: 4
# Komentar owner_resp_text: ['Dear Mark Thank you for your review, We will use them to improve our service Best Regards, Pondok Pitaya', "Dear Kim Thank you for your review We're glad you had decent experience and we appreciate your suggestions we will use them to improve our service Best Regards, Pondok Pitaya", "Dear Karen Thank you so much for your kind review we're happy to hear that a great experience with us. we look forward to welcoming you again Best regards, Pondok Pitaya", "Dear Heidi Thank you for your kind review. we're happy to hear that a great experience with us. we look forward to welcoming you again Best Regards, Pondok Pitaya"]

# %% [markdown]
# ## 4. Room View

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap room_view
'''
count_gender = df.groupby('room_view').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="room_view", 
    title="room_view",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#                           room_view  jumlah
# 1                 One-Bedroom Suite     203
# 2  Standard Twin Room with Sea View      13
# 3                 Two-Bedroom Villa      13
# 5                    Villa 4 Adults      13
# 4      Two-Bedroom Villa (6 Adults)       9
# 0                                 0       6

# %% [markdown]
# ## 5. Stay Duration

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_duration
'''
count_gender = df.groupby('stay_duration').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(count_gender)  
plot_barplot(
    data=count_gender,
    x_col="jumlah",
    y_col="stay_duration", 
    title="stay_duration",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#    stay_duration  jumlah
# 8       3 nights      67
# 6       2 nights      56
# 0        1 night      42
# 9       4 nights      39
# 10      5 nights      14
# 11      6 nights      13
# 12      7 nights       7
# 13      8 nights       6
# 14      9 nights       4
# 4      14 nights       3
# 2      11 nights       2
# 1      10 nights       1
# 3      13 nights       1
# 5      16 nights       1
# 7      27 nights       1

# %% [markdown]
# ## 6. Stay Type

# %%
''' 
Membuat sort list dan visualisasi banyak orang tiap stay_type
'''
stay_type = df.groupby('stay_type').size().reset_index(name='jumlah').sort_values(by='jumlah', ascending=False)
print(stay_type)  
plot_barplot(
    data=stay_type,
    x_col="jumlah",
    y_col="stay_type", 
    title="stay_type",
    format_number="",
    x_label="Banyak",
    colour_bar_set="1"
)
# Out:
#         stay_type  jumlah
# 0          Couple     112
# 1          Family      62
# 3  Solo traveller      48
# 2           Group      35

# %% [markdown]
# ## 7. Tahun Review

# %%
# --- 1. DATA PREPARATION ---

# Pastikan kolom tanggal bertipe datetime
# Jika format tanggalmu beda (misal: "12 Dec 2023"), pandas biasanya otomatis mengenali
df['review_post_date'] = pd.to_datetime(df['review_post_date'])

# Ekstrak tahun ke kolom baru
df['year'] = df['review_post_date'].dt.year

# Hitung jumlah review per tahun dan URUTKAN BERDASARKAN TAHUN (sort_index)
# Kita pakai sort_index() agar tahunnya urut (2020, 2021, 2022...), bukan acak.
year_counts = df['year'].value_counts().sort_index()

# Konversi ke DataFrame agar mudah di-plot seaborn
year_df = year_counts.reset_index()
year_df.columns = ['tahun', 'jumlah']

# --- 2. VISUALISASI (Best Practice) ---

# plt.figure(figsize=(10, 6))

# Gunakan satu warna (misal: biru) karena ini data waktu, tidak perlu warna-warni 
# kecuali Anda ingin menghighlight tahun tertentu.
plot_barplot(
    data=year_df,
    x_col="tahun",
    y_col="jumlah", 
    title="jumlah",
    format_number="",
    x_label="tahun",
    colour_bar_set="1"
)
# year_df

# %%
df['Year'] = df['review_post_date'].dt.year

# Reset index agar 'Year' kembali menjadi kolom
rating_year = df.groupby('Year')['rating'].mean().reset_index()

# Opsional: Urutkan tahun biar rapi
rating_year = rating_year.sort_values('Year')

print(rating_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_year, 
    x_col="Year", 
    y_col="rating", 
    title="Rata-rata Rating per Tahun", 
    x_label="Tahun",
    y_label="Skor Rating",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#    Year    rating
# 0  2022  9.333333
# 1  2023  8.369863
# 2  2024  8.293333
# 3  2025  7.613208

# %%
# Filter dulu: Ambil hanya data yang 'review_text_disliked' BUKAN 0
filtered_df = df[df['review_text_disliked'] != 0]

# Baru di-grouping
dislike_by_year = filtered_df.groupby('Year')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Tahun ===")
for year, comments in dislike_by_year.items():
    print(f"Tahun {year}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per Tahun ===
# Tahun 2022: Ditemukan 1 komentar dislike.
# ['it’s a bit far from the centre of time. For Yoga and Surfing fanatics, it’s worth the trip. My kids and I are neither of those so we missed the buzz of the city and the shopping which we enjoy the most when traveling for leisure.']
# ------------------------------
# Tahun 2023: Ditemukan 32 komentar dislike.
# ['Not the fault of the hotel, but after a big rain, the water quality for surfing got really bad. We had to stay out of the water for two days.', 'No fridge mirror in bathroom to high vanity tap to high slashing water everywhere', 'Dogs barking', 'Mattress a bit hard and only 2 small pillows. Rooms decent but needing some maintenance.', 'Shame the sea was so dirty', 'No tea or coffee or cups provided in the villa', 'I stayed in C3 which was super clean but quite small and dark. I know it was high season but to be honest I think it was expensive at more than $100AUD per night. I think it would also be ok to eliminate smoking from restaurant🙏', 'Rooms are very dark, and walls are paper thin.', 'very small rooms', 'Bintang expensive!', 'It was perfect retreat from the other busy beaches of Bali', '-', 'They don’t serve breakfast until 8 AM and both mornings it took them 40 minutes to deliver my kids breakfast so they couldn’t eat until 8:40am….', 'Nothing', 'Nothing', 'nothing it was amazing', 'We got unlucky with the rain but the property was everything we expected', 'Security very bad , staff not friendly. Room service & food options too limited. No value for money.', 'First world problem… the water got cold very quickly.', 'the bathrooms', "A major issue here for our family and many others which we spoke to there was the staff lacking in communication and service, we had to wait approximately 1 hour for each meal (nothing too fancy either, just a regular fish and chips) and the opening hours of the restaurant were very short going from 8am - 9pm. The only other minor issues for us was the wifi, it was incredibly slow and hard sometimes to access the internet, emails, movies etc., and the hot water was very limited to only 1 minute of hot water and then it would be cold for the next person/s to use the shower. Overall, would highly recommend to families and people who enjoy yoga as there are yoga classes there (although we don't do yoga) and we would definitely stay here again.", 'unstaffed, pool not cleaned, old, basic everything.. just get by doing the least they can .. property old and gross', 'Rooms were great but as they are made from natural materials the air-conditioning finds it hard to cool the room, suggest a small fan to be available for hire or to buy.', 'No fridge in the room', 'Obwohl es als Yoga und Surf Camp verkauft wird wurden keine Yoga Stunden angeboten! Strand dreckig', 'Väntade länge på mat', 'Gehorige hutjes. Geen plek om je spullen goed weg te leggen ( plekje voor koffer/ tas ontbreekt. Geen plek in de badkamer om spulletjes weg te zetten. Geen lopende kraan bij de wasbak.', 'Das Zimmer river suite war sehr dunkel und ich glaube auch ein paar Käferchen waren im Zimmer aber ist die traditionelle alte Bauweise da mann kan glaube ich nichts machen', '- wenig Möglichkeiten, die Sachen aufzuhängen', 'Tidak ada', 'leider ist das Hotel in die Jahre gekommen, ich war 2019 schon einmal dort, da war der Service, die Sauberkeit und das Essen viel besser', 'rien']
# ------------------------------
# Tahun 2024: Ditemukan 37 komentar dislike.
# ['. Had trouble in room with wifi connection, but wifi was good at the restaurant.', 'Some mosquitos still can get into rooms even with doors shut.', 'The mattress was too firm', 'Some facilities could use a revamp.', 'Mosquitoes in my room and no nets.', 'Uncomfortable hard bed, only 2 pillows. Breakfast very average, menu needs upgrade. Need to stock soy or oat milk. No avocado or oats on offer. Coffee not so great. Outside bathroom. Not so clean. View of sea through the bathroom. Pool old and not maintained. The rubbish out the front of resort needs to be cleaned up. No fridge in room. No tv in room. More like 3 star not 4 star. Dogs in the area fighting.', 'Location', 'The bathroom (which was semi outside) was cute, but smelt musty and toilet also smelt sometimes..', "Obviously a surfing spot. didn't enjoy beach. Black sand and quite rough under foot", 'No fudge in room.', 'Beds were extremely firm and no bar fridge to keep drinks cold', 'The wifi reception didn’t work in our room & the outdoor bathroom sounded nice but meant there were lots of insects coming in at night when the light was on. Not a big deal to us but probably not for everyone.', 'Pool water quality was not maintained', 'Pool needs a bit of work', 'Bed was extra extra firm with only one pillow each. Bathroom on the balcony is ok if you are a guy otherwise the neighbours and people walking by can get an eye full as walls only waist high.', "wifi was not great unless you stood right next to the router. But also then it wasn't very good. Pillows could have been a bit more comfy but that is personal I suppose. Big and a bit hard and only 1 pillow. Im sure they would have given me another pillow if I asked, but I only remembered it late at night when staff had gone home. And see above regarding cash.", 'A bit old Maybe.', 'All was great', 'The pool has many missing tiles, could easily hurt someone. No fridge in the room, had to keep asking for ice from the restaurant to have cool water. Kept banging head on low door cornice. Padlock for doors. Nowhere to put surfboards', 'Felt a car would be beneficial..a bit isolated..', 'Some areas are only accessible by stairs. Mom can walk but can’t do large stairs. Not the properties fault, I did not setup our ride prior and it is hard to find on a ride share because it is not in the busy tourist area.', 'The restaurant was a bit pricey but the staff were amazing❤️', "There was a kettle in the room but no tea or coffee facilities. When I asked at the kitchen, they said that they could lend us some cups, ,but nothing else. I think for the price this is not satisfactory. The restaurant food was a bit expensive. The breakfast sounded good but wasn't. We both had the Super breakfast which was strange, instead of toast it was served with 2 very oily hash browns. I saw a man eating scrambled eggs with toast but that was not included in the breakfast choices included in our booking. The coffee was Bali coffee, very strong. On both occasions at the restaurant we were joined by a dog, which sat there waiting to be fed. I like dogs, but not in restaurants. In short, it is a fantastic location, but is a bit tired now and not good value for money", 'Some of the other reviews are a little harsh in our opinion. It’s a great place. Come and enjoy.', 'It was too expensive for what it was. Rooms were small, water cut out, poor wifi,no view of the beach, no coffee or tea supplied, unhelpful staff. It was very poor.', 'expensive', 'A fridge in the room would be good', 'Nothing really!', 'Price value, small room', "No fan in room,room dark and gloomy no phon to call in room.. No teh,or coffee in room No fridge..other Ordered,nasi Goreng,staff bring mie goreng..breakfast was average not up to standard for the price..swimming pool was dirty And filters not working.. Then pool was over chlorinated and wasn't usable.. I wouldn't stay again with this hotel..", 'Felt overpriced. Bed was very uncomfortable, very hard. Room was very small and everyth ...
# ------------------------------
# Tahun 2025: Ditemukan 49 komentar dislike.
# ['Hotel a little run down', 'Small fridge in room would be good', 'Nothing, it could do with a strong water pressure over all the outdoor paths and stones to bring it back that’s all. It was all lovely. Great breakfast included too!', 'Needs minor repairs/ maintenance, but didn’t really bother me', 'Bugs', 'Would have been nice to have fruit included in breakfast as I don’t eat ebggs', 'I had an overnight stay and it suited me well however there was a lot of light first thing in the morning (which suits if you are after an early surf).', 'The food could be', 'The bathrooms in the rooms need to be updated as were a bit small and quite tired. Also could maintain the access to the beach a lot better as there was a lot of logs and some rubbish straight out in front which made access not the easiest and would be simple to clean up.', 'No fridge in room s', 'One of the toilets leaked and was a bit smelly which will need to be fixed.', 'It needs a couple of minor things like a fridge in the room and mosquito netting. The restaurant staff need to be better trained in customer service as they stand around talking unless you specifically call them over. The rooms are very basic but functional.', 'No TV. Not that it was a big problem for us though.', 'The pool needs an upgrade but still clean & nice.', 'The (tap) water smelled like it came straight from the adjacent river... Otherwise no complaints', 'Pool is a bit dated but great views of the ocean', "Breakfast doesn't start until 8am", 'No fridge or tv in room', 'Would have been nice to have a refrigerator in the room or at least a communal refrigerator to store drinks etc. Also the sliding door to the bathroom was very difficult to move.', 'The location is quite isolated from the main tourist area so long drives were needed to visit anywhere. The beach is more suitable for surfing than swimming with a strong riptide. When they ran out of coconuts on our second day they didn’t restock which was annoying.', 'One thing that could be improved is the music in the café. It would be great to hear something more traditional or calm and chill, rather than loud pop tracks that don’t quite match the vibe of the place. The only other downside is the price, which feels about 20% higher than expected, especially with cheaper options nearby. Still, I return every time because this place has become a meaningful part of my Bali experience.', 'No bottled water in the restaurant.', "* what I didn't like most was no e-mail contact, they offered to organize transport, but when we asked by e-mail or booking how much the transfer from Ubud would cost, there was no answer, we organized it by ourselves. If my e-mails wouldn't have been ignored, I would give 9 note. * the bottom of the pool needs renovation because some of the ceramic tiles fell off and it looked messy", 'The room was didgusting and smelly', 'No fridge in room', 'Messaged property saying would arrive earlier than check in time to go surf - no reply. Arrived and just wanted to put my stuff somewhere to go surf skate - suggested I leave my things in the floor - despite the allocated room being empty The double bed I’d booked was two singles pushed together Went down for coffee 07:30 - all staff there - but told we don’t open till 8. Included breakfast was different to one on menu and was disgusting. Everything you ask for is apology but not possible. Great spot but would never stay again. Appalling customer service - avoid.', 'Location is too far from anything. Room was big and good but amenities were not enough. Also showers were very camping style. No slippers.', 'The facilities are in need of some general maintenance.', 'Tout le reste : - Poorly insulated rooms: we could hear everything happening in neighboring rooms and outside, making nights difficult. - Very few sun loungers, already insufficient for hotel guests and often taken by outsiders (who pay only 50K rupiah to use the pool). As a result, we had to wake up very early to "reserve" a ...
# ------------------------------

# %%
# Filter dulu: Ambil hanya data yang 'review_text_disliked' BUKAN 0
filtered_df = df[df['review_text_liked'] != 0].copy()

# Baru di-grouping
dislike_by_year = filtered_df.groupby('Year')['review_text_liked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik like per Tahun ===")
for year, comments in dislike_by_year.items():
    print(f"Tahun {year}: Ditemukan {len(comments)} komentar like.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik like per Tahun ===
# Tahun 2022: Ditemukan 1 komentar like.
# ['the staff the most. they were exceptionally kind. I loved the garden and the feel of nature second.']
# ------------------------------
# Tahun 2023: Ditemukan 44 komentar like.
# ['Great location, attentive staff and unique decor. This was one of our favorite places to stay on Bali. We had massages from Ria that were AMAZING. Food was better than expected and a great value. Good air conditioning and clean rooms.', "Amazing location, above what we expected. Value for money wise, this place is top notch. If you've been to the kommune, it's like a poor mans version of that", 'Breakfast was very good excellent location', 'Close to the surf', 'Great location at surf beach. Good restaurant and lovely staff. Best massage service out of our stay :)', 'Amazing location on Balian Beach. Surf was amazing & right at the door.', 'Fantastic hospital staff', 'Location and surf', 'Large villa with beautiful view of the ocean. Friendly staff.', 'I’ve stayed before as the beach front location is unbeatable. The Healthy Breakfast included was fresh clean and delicious. The yoga with Valentina was fantastic and massage with Ayu was the best I’ve had ever in Bali! All the staff we warm friendly and helpful. The day I arrived the weather was wild and wet but staff remained positive and continually mopped wiped and maintained the restaurant 🙏', 'Great location, goog value & great staff.', 'Location is perfect, right on the beach. The garden and grounds and beautiful. Staff are pleasant and helpful.', 'great location, great food and excellent massage', 'The location is great and the rooms are nice enough. The owners have let the property get a bit rundown but they were working on fixing things up a bit', 'Right at the beachfront and great breakfast choice', 'Good location, Good food, friendly staff. Lovely grounds.', 'Perfectly situated on Balian Beach with surf just outside your doorstep. Food was exceptional, room was as Balinese as it gets. The beach is a black sand with rounded rocks dotting the shore. Surf comes with both right and left hand breaks as short distance from shore. It should be noted that the hotel is adjacent to a river flowing into the ocean and there is a significantly dangerous rip that makes this not a good place to swim. The hotel Spa is very nice and the massage was both relaxing and therapeutic.', 'Awesome', 'The hotel is beautiful and clean, located away from the crowds and surrounded by exotic nature. You can enjoy delicious breakfasts by the ocean. The hotel staff is very friendly. The lady at the reception helped us a lot in an emergency situation. We send her our best regards! This stay was the best of all the places we visited in Bali. We would like to come back someday.', 'Great location and yoga facilities', 'Super cute place to stay in! Staff are nice, room is clean and cozy! Love the room and the outdoor shower. It’s feels very Balinese vibe which I love!', 'Staff fantastic and very clean', 'Everything was perfect', 'Perfect spot in Balian', 'Nothing', 'It was very relaxing listening to the ocean on your porch. The grounds were cared for and looked amazing!', 'the beach', 'The Pondok Pitaya is a great location for a family of surfers. We enjoyed our stay in the Happy House with a clean and spacious room with 6 beds, it was comfortable and affordable. The view of the surf was great from the pool area with a clean (sort of) and great pool to hang out at for the day. There are many places to go for walks up the streets and many mini marts and restaurants but nothing more to do than what is available at the hotel and surf for an activity unless you want to drive. The staff were very friendly.', 'on the surf break', 'Perfect location and perfect rooms, secluded and right on the beach!', 'The location on the beach is perfect. A beautiful little village. The staff were fantastic. They even sent me an item that we left behind to our next location.', 'Großzügige Außenbereiche Sehr nettes Personal Gutes Essen', 'Lokasi restaurant pemandangan laut yg indah. Staff yang ramah dan helpful Room dengan nuansa traditional. Taman yg sejuk.', 'Ok', 'De locatie, het restaurant, het bovengemiddelde ontbijt, vri ...
# ------------------------------
# Tahun 2024: Ditemukan 48 komentar like.
# ['The staff are fantastic and the food is delicious. Ideal surf spot and hidden away gem to get a real local feel.', 'Lovely property. Grounds well maintained, rooms very clean, staff exceptionally friendly and helpful. Hotel arranged our private transport to next hotel 2 1/2 hrs away and allowed us to pay with our credit card.', 'Location and very authentic balanese decor and buildings', 'Peaceful location, very clean and staff are friendly. The breakfasts were fantastic.', 'Location is great. Resort gardens are well kept. Pool in front of the beach. Staff were very friendly and accomodating.', 'location, staff and good atmosphere. Also awesome massages.', 'The location is perfect. Staff super friendly. Great surf spot. Quieter area. Great restaurants around. Casa, mojos and Yama with nice food and coffee. Went to Nicki’s yoga up the road. We hired a motorcycle to get around. Wifi ok.', 'Located right on the beach, best location in town', 'Perfect location for a quiet get away. Staff were excellent, beach was lovely and would recommend it highly. Extremely relaxing.', 'Good surf and peacefull setting9', 'Outlook over the ocean was fabulous, food good, room ok, close to other bar’s & eateries..', 'good view of surf', 'Family friendly and good location', 'Location', 'The best location in Balian', 'All of staff were friendly and helpful, big smiles and happy to chat about anything. Perfectly located at the beach doorstep.', 'My husband, myself & 10 year old son stayed here & loved it! A quiet surfing village, very relaxed no thumping beach clubs like in hectic Canggu. The hotel restaurant had a fantastic range of food & healthy options, very relaxing to sit & watch the waves roll in. Lovely beach walks on black volcanic sand & stony shore. Excellent customer service & very friendly staff. The 2 bed villa was clean & beautifully decorated with comfy beds.', 'Beautiful settings & good rooms with really friendly helpful staff', 'Construction using old Javanese Joglos made interesting rooms. Location directly on Balian Beach is the best !', 'Great spot. Good food!', 'Staff and location', "Great location of this hotel right by the beach. Really lovely place to sit and have the delicious breakfast they served at the hotel. Room was clean, shower good and bed comfortable enough. Bathroom is outside which we loved. Staff was super helpful and friendly. Balian Beach is a beautiful place. So much more quiet than other places we have been to in Bali. We absolutely loved it. At the start we weren't sure but now its one of the highlights of our trip even though we are no surfers. I wanted to take lessons but the waves were pretty darn high so didn't dare :). We went for twice a day for yoga with Niki @balianspirityoga that was a short walk from the hotel. Yoga at the hotel was not happening when we were there as too quiet (end of feb) but Niki is a fantastic teacher so glad it wasn't happening at the hotel or I wouldn't have met Niki. We finished each night at Rekis Warung a brilliant spot for sunset and delicious local foods. Make sure to bring cash to Balian as many places do not take cards and the nearest cashpoint don't accept most of the European cards. We had to take a taxi for 30 minutes to get to a cashpoint that took our cards.", 'Perfect location and realy sweet staff. Clean room.', 'Great location, excellent staff, good food', 'Great location', 'Fantastic location, nice lawn, friendly helpful staff.', 'The property was great.. spacious room and ensuite, kettle and coffee facilities. Lovely staff and great pool..', 'The staff are exceptional. So nice and helpful. We have limitations with stairs and severe asthma from smoke which made the lounge area difficult to eat in. They were very accommodating finding solutions. The location is gorgeous and off the beaten path. The staff worked hard and found me a driver to my next location.', 'Right on the surf break with a lovely pool', 'The location was excellent, as were the staff.', 'Ever ...
# ------------------------------
# Tahun 2025: Ditemukan 64 komentar like.
# ['Location right on the beach, asked for a fridge and they brought us one within an hour', 'Amazing location good facilities And great staff', 'The property is on the beach and is large. It has everything you need. I liked the massage here, better than the other one in the street, and the views of the surf. We were watching the surfers all the time and my hubby had a great time surfing. Also loved Nikki’s yoga classes up the road, strong but fantastic too. We had a relaxing stay overall.', 'Our stay at Pondok Pitaya Balian Hotel was great, it is a beach front hotel with great views of the surf break from the restaurant, pool or gardens. Our room was situated on the 2nd level with limited views from the open bathroom of the beach/break but was still comfortable and clean. The staff were warm and friendly and the breakfast options were tasty and freshly made.', 'Location and the space around the property. It was relaxing and quiet. I had one of the separate bungalows at the front and could check the surf from my front door.', 'Great location', 'Fabulous beachfront location. Comprehensive menu at restaurant. Spa treatments available. Room was rustic but clean and comfortable with outdoor bathroom. Swimming pool and ocean view room.', 'Fantastic place to stay right in front of shipwrecks surf break', 'Beautiful and peaceful.', 'Perfect location.', 'Great location', 'Fantastic location right on the beach with views to the surf break from the pool and restaurant. Rooms were very cute Balinese style and grounds were well maintained and the staff very attentive and friendly. Short walk to several other warungs and restaurants.', 'Location', "Beautiful location. Quite out of the way tho. 3 to 4 hours from Denpasar airport. Came here because my husband surfs and kite surfs. I don't think you'd come here as a destination unless you're a surfer. The sand is black and rocky. I didn't swim at the beach, just the pool. There are no shops or cafes anywhere close. You'd need transport to take you into the nearest town, but that didn't worry us as we weren't after that kind of trip, and were very happy to stay put in the hotel the whole time, just relaxing and unwinding from our busy lives. We both practise Yoga and there are 2 lovely Yoga shalas. One overlooking the beach, the other nestled in the garden area around the back. We stayed in one of the house/bungalows. We had A/C, a fridge and a kettle. Some rooms do not have this so if that's important to you make sure your room has this. Those 3 are deal breakers for us. There are also a whole set of basic rooms, and a few other types of rooms which some travellers may be totally fine with. Just depends on what you're after. Look into it before you book so you know what to expect from your room. The staff are friendly and such warm people. The food at the restaurant is great. Generous breakfast was included. If you order food at the restaurant, it takes a while to come out but that didn't bother us at all, being on a holiday and not in a rush. Gave us time to sit, read, talk and chill. Other guests are friendly, nice people, rather than the posey, loud, drunk vibe you might get at busier resorts down south. The rooms are made up and cleaned beautifully. We had 2 bathrooms. One of the toilets leaked and was a bit smelly which will need to be fixed. Daily yoga is fantastic, the teacher was brilliant and a beautiful friendly person. We will come back, hopefully next year.", 'Location is excellent , staff were very friendly', 'It’s right on the beach. Great for surfers. It’s at the end of a road so very little traffic to contend with. Traditional Balinese type rooms with beautiful gardens.', 'Perfect location for surfing Balian. Great for young families or couples looking for a quiet Bali paradise.', 'Beach front. Very romantic little villa. Food was nice. Walking distance to other places to eat out. The gardens & space is beautiful.', 'Lovely sea view of the surf from the restaurant', 'There was n ...
# ------------------------------

# %%
# Reset index agar 'Year' kembali menjadi kolom
rating_room_year = filtered_df.groupby('room_view')['rating'].mean().reset_index()

rating_room_year = rating_room_year[rating_room_year!= 0]

# Opsional: Urutkan tahun biar rapi
rating_room_year = rating_room_year.sort_values('rating')

print(rating_room_year)

# --- CARA PENGGUNAAN ---
plot_barplot(
    data=rating_room_year , 
    x_col="rating", 
    y_col="room_view", 
    title="Rata-rata Rating per room_view", 
    x_label="Skor Rating",
    y_label="Room View",
    colour_bar_set="1" # Gunakan 3 (Biru) untuk data tahunan agar netral
)
# Out:
#                           room_view    rating
# 5                    Villa 4 Adults  5.142857
# 2  Standard Twin Room with Sea View  7.375000
# 1                 One-Bedroom Suite  7.865079
# 3                 Two-Bedroom Villa  7.875000
# 4      Two-Bedroom Villa (6 Adults)  8.500000
# 0                               NaN  9.000000
# /tmp/ipykernel_12391/1757560589.py:27: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   barplot = sns.barplot(

# %%
filtered_df = df[df['review_text_disliked'] != 0].copy()
# Baru di-grouping
dislike_by_room_view = filtered_df.groupby('room_view')['review_text_disliked'].apply(list)

# --- CARA MENGAKSES HASILNYA (Sama seperti kodemu) ---
print("=== Statistik Dislike per Kamar ===")
for room_view, comments in dislike_by_room_view.items():
    print(f"Pada {room_view}: Ditemukan {len(comments)} komentar dislike.")
    print(f"{comments}") 
    print("-" * 30)
# Out:
# === Statistik Dislike per Kamar ===
# Pada 0: Ditemukan 2 komentar dislike.
# ['No fridge in the room', 'more towells']
# ------------------------------
# Pada One-Bedroom Suite: Ditemukan 92 komentar dislike.
# ['Hotel a little run down', 'Nothing, it could do with a strong water pressure over all the outdoor paths and stones to bring it back that’s all. It was all lovely. Great breakfast included too!', 'Would have been nice to have fruit included in breakfast as I don’t eat ebggs', 'I had an overnight stay and it suited me well however there was a lot of light first thing in the morning (which suits if you are after an early surf).', 'The food could be', 'The bathrooms in the rooms need to be updated as were a bit small and quite tired. Also could maintain the access to the beach a lot better as there was a lot of logs and some rubbish straight out in front which made access not the easiest and would be simple to clean up.', 'No fridge in room s', 'It needs a couple of minor things like a fridge in the room and mosquito netting. The restaurant staff need to be better trained in customer service as they stand around talking unless you specifically call them over. The rooms are very basic but functional.', 'No TV. Not that it was a big problem for us though.', 'The pool needs an upgrade but still clean & nice.', 'The (tap) water smelled like it came straight from the adjacent river... Otherwise no complaints', "Breakfast doesn't start until 8am", 'No fridge or tv in room', 'Would have been nice to have a refrigerator in the room or at least a communal refrigerator to store drinks etc. Also the sliding door to the bathroom was very difficult to move.', 'The location is quite isolated from the main tourist area so long drives were needed to visit anywhere. The beach is more suitable for surfing than swimming with a strong riptide. When they ran out of coconuts on our second day they didn’t restock which was annoying.', 'One thing that could be improved is the music in the café. It would be great to hear something more traditional or calm and chill, rather than loud pop tracks that don’t quite match the vibe of the place. The only other downside is the price, which feels about 20% higher than expected, especially with cheaper options nearby. Still, I return every time because this place has become a meaningful part of my Bali experience.', 'No bottled water in the restaurant.', '. Had trouble in room with wifi connection, but wifi was good at the restaurant.', 'Some mosquitos still can get into rooms even with doors shut.', 'The mattress was too firm', 'Mosquitoes in my room and no nets.', 'Uncomfortable hard bed, only 2 pillows. Breakfast very average, menu needs upgrade. Need to stock soy or oat milk. No avocado or oats on offer. Coffee not so great. Outside bathroom. Not so clean. View of sea through the bathroom. Pool old and not maintained. The rubbish out the front of resort needs to be cleaned up. No fridge in room. No tv in room. More like 3 star not 4 star. Dogs in the area fighting.', 'Location', 'The bathroom (which was semi outside) was cute, but smelt musty and toilet also smelt sometimes..', "Obviously a surfing spot. didn't enjoy beach. Black sand and quite rough under foot", 'No fudge in room.', 'Beds were extremely firm and no bar fridge to keep drinks cold', 'Pool water quality was not maintained', 'Pool needs a bit of work', 'Bed was extra extra firm with only one pillow each. Bathroom on the balcony is ok if you are a guy otherwise the neighbours and people walking by can get an eye full as walls only waist high.', "wifi was not great unless you stood right next to the router. But also then it wasn't very good. Pillows could have been a bit more comfy but that is personal I suppose. Big and a bit hard and only 1 pillow. Im sure they would have given me another pillow if I asked, but I only remembered it late at night when staff had gone home. And see above regarding cash.", 'A bit old Maybe.', 'Not the fault of the hotel, but after a big rain, the water quality for surfing got really bad. We had to stay out of the water for two days.', 'No fridge mirror in bathroom to high vanity tap to high slashing water everywhere ...
# ------------------------------
# Pada Standard Twin Room with Sea View: Ditemukan 6 komentar dislike.
# ['Small fridge in room would be good', 'Bugs', 'The room was didgusting and smelly', 'The facilities are in need of some general maintenance.', 'RAS', 'Bastante sucia.la parte de playa, una pena, pero es increíble la ubicación frente a la playa de Balian']
# ------------------------------
# Pada Two-Bedroom Villa: Ditemukan 7 komentar dislike.
# ['Needs minor repairs/ maintenance, but didn’t really bother me', 'Some facilities could use a revamp.', 'The wifi reception didn’t work in our room & the outdoor bathroom sounded nice but meant there were lots of insects coming in at night when the light was on. Not a big deal to us but probably not for everyone.', 'Shame the sea was so dirty', 'nothing it was amazing', 'Alles ein bißchen in die Jahre gekommen, verbraucht und ein wenig schmuddelig', 'De douche van de ene slaapkamer werkte niet. De andere gelukkig wel']
# ------------------------------
# Pada Two-Bedroom Villa (6 Adults): Ditemukan 5 komentar dislike.
# ['One of the toilets leaked and was a bit smelly which will need to be fixed.', 'Pool is a bit dated but great views of the ocean', 'Nothing', 'First world problem… the water got cold very quickly.', "A major issue here for our family and many others which we spoke to there was the staff lacking in communication and service, we had to wait approximately 1 hour for each meal (nothing too fancy either, just a regular fish and chips) and the opening hours of the restaurant were very short going from 8am - 9pm. The only other minor issues for us was the wifi, it was incredibly slow and hard sometimes to access the internet, emails, movies etc., and the hot water was very limited to only 1 minute of hot water and then it would be cold for the next person/s to use the shower. Overall, would highly recommend to families and people who enjoy yoga as there are yoga classes there (although we don't do yoga) and we would definitely stay here again."]
# ------------------------------
# Pada Villa 4 Adults: Ditemukan 7 komentar dislike.
# ['No tea or coffee or cups provided in the villa', 'Location is too far from anything. Room was big and good but amenities were not enough. Also showers were very camping style. No slippers.', 'Nothing', 'The buildings were getting old and run down. Termites and roaches in the rooms.', 'Security very bad , staff not friendly. Room service & food options too limited. No value for money.', 'Uns hat ein bisschen die Liebe zum Detail in der Villa gefehlt, so wie wir es eigentlich von Indonesien gewöhnt sind.', 'Bei Ankunft haben wir eine dreckige Wohnung vorgefunden. Der Boden war nicht sauber, voller Krümel, Sand, Tierkot. Die Handtücher haben gestunken und waren fleckig. Die gesamte Unterkunft war stickig und modrig. wir haben gebeten, die Unterkunft noch mal zu reinigen. Anschließend war der Boden leider immer noch völlig dreckig. so dass wir erneut das Servicepersonal bemühen mussten. Sehr unangenehm für alle. Die Armaturen im Bad waren unbeschreiblich rostig, alt ä, schmutzig. Aus dem Wasserhahn ist braune Brühe heraus gelaufen. Der Wasserkocher war total verkalkt. Auch dies mussten wir leider ansprechen, der Wasserkocher wurde freundlicherweise ausgetauscht und auch die Armaturen wurden überraschenderweise gewechselt. Allerdings waren diese nicht kompatibel, so dass sie ständig abgefallen sind und wir eine Fontäne im Bad hatten. Es gibt leider keine Moskitonetze in dieser Unterkunft, was notwendig wäre. Die Klimaanlage ist mehrfach ausgefallen und wurde durch das Personal immer wieder repariert. Nachts haben wir natürlich niemanden hierfür bemüht, was dann zu sehr stickigen Verhältnissen geführt hat. Der Pool ist alt, es fehlen viele Kacheln oder sind zum Teil abgebrochen, aber keiner kümmert sich darum, diese zu reparieren. Die Unterkunft ist zwar nahezu direkt am Strand, es gibt aber keinen Weg, sondern man steigt über einigen Müll und zum Strand zu gelangen. Dies könnte man auch etwas netter gestalten mit einem kleinen Weg. Beim Frühstück kann man aus drei Optionen wählen (lediglich eine vegetarische Option, eine indonesische Option). Das Frühstück wird völlig lieblos zubereitet, das Omelette enthält keinerlei Gemüse oder zumindest etwas grüne Kräuter oder sonstige Dekoration. Es gibt lediglich eine Scheibe weißen Toast dazu. Man kann Obst mit Joghurt und Granola wählen. (die ersten beiden Tage gab es aber kein Müsli, obwohl man im Laden direkt gegenüber Müsli kaufen kann).']
# ------------------------------

# %%
sns.lineplot(data=df, x='review_post_date', y='rating')
# Out:
# <Axes: xlabel='review_post_date', ylabel='rating'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
# Out:
# /tmp/ipykernel_12391/2148740873.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.set_index(date_col).resample('M').size()
# review_post_date
# 2025-09-30    23
# 2025-10-31    15
# 2025-08-31    14
# 2025-05-31    11
# 2025-07-31    11
# 2023-03-31    10
# 2025-01-31    10
# 2024-06-30     9
# 2024-09-30     9
# 2024-05-31     9
# 2024-08-31     8
# 2023-08-31     8
# 2023-10-31     8
# 2024-10-31     8
# 2023-07-31     8
# 2023-06-30     8
# 2024-07-31     8
# 2025-06-30     7
# 2023-05-31     6
# 2023-04-30     6
# 2024-03-31     6
# 2024-12-31     5
# 2023-02-28     5
# 2023-01-31     4
# 2024-04-30     4
# 2023-12-31     4
# 2025-11-30     4
# 2023-09-30     4
# 2024-11-30     4
# 2025-02-28     4
# 2025-04-30     4
# 2022-12-31     3
# 2024-02-29     3
# 2025-03-31     2
# 2024-01-31     2
# 2023-11-30     2
# 2025-12-31     1
# dtype: int64

# %%
import pandas as pd

# 1. Pastikan kolom target sudah format datetime
col_name = 'review_post_date'  # Sesuaikan nama kolom tanggal Anda
df[col_name] = pd.to_datetime(df[col_name], errors='coerce')

# 2. Urutan bulan yang benar (agar tidak terurut abjad April duluan)
bulan_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 
    'July', 'August', 'September', 'October', 'November', 'December'
]

# 3. Ambil nama bulan dan hitung
# dt.month_name() mengambil nama bulan (Jan, Feb, dst) mengabaikan tahun
monthly_counts = df[col_name].dt.month_name().value_counts()

# 4. Urutkan hasil sesuai kalender (bukan jumlah terbanyak)
monthly_counts = monthly_counts.reindex(bulan_order, fill_value=0)

# 5. Tampilkan Hasil
print("--- Total Data Per Bulan (Akumulasi Semua Tahun) ---")
print(monthly_counts.sort_values(ascending=False))

# --- Opsional: Tampilkan dalam Grafik Batang ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
monthly_counts.plot(kind='bar', color='teal')
plt.title('Total Review Berdasarkan Bulan (Musiman)')
plt.xlabel('Bulan')
plt.ylabel('Total Jumlah Review')
plt.xticks(rotation=45)
plt.show()
# Out:
# --- Total Data Per Bulan (Akumulasi Semua Tahun) ---
# review_post_date
# September    36
# October      31
# August       30
# July         27
# May          26
# June         24
# March        18
# January      16
# April        14
# December     13
# February     12
# November     10
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Pastikan kolom tanggal dikenali sebagai datetime
# Ganti 'published_at_date' dengan 'review_post_date' jika Anda sudah merename kolomnya
date_col = 'review_post_date' 
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# 2. Resample data per Bulan (M) dan hitung jumlahnya (.size())
# Kita set tanggal sebagai index dulu agar bisa di-resample
monthly_counts = df.set_index(date_col).resample('M').size()

# 3. Plotting
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-', color='#1f77b4', linewidth=2)

# Mempercantik tampilan
plt.title(f'Tren Jumlah Review per Bulan', fontsize=14)
plt.xlabel('Bulan & Tahun', fontsize=12)
plt.ylabel('Frekuensi Data', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()

# Tampilkan
plt.show()
monthly_counts.sort_values(ascending=False)
